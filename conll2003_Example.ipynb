# %% [markdown]
# # Imports

# %%
import numpy as np

# Add these lines if you clone from https://github.com/fdalvi/NeuroX
# import sys
# sys.path.append("/path/to/NeuroX")
# In the case of the notebook, the path is the parent directory
import sys
sys.path.append("..")

# %% [markdown]
# # Data

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.0.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 6.0 MB/s eta 0:00:01
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 22.9 MB/s eta 0:00:01
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 18.3 MB/s eta 0:00:01
# Collecting dill
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 18.2 MB/s eta 0:00:01
# Collecting tqdm>=4.62.1
#   Downloading tqdm-4.63.0-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 18.9 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from datasets) (4.5.0)
# Requirement already satisfied: dataclasses in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from datasets) (0.8)
# Requirement already satisfied: numpy>=1.17 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from datasets) (1.19.5)
# Requirement already satisfied: pandas in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from datasets) (1.1.5)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
#      |████████████████████████████████| 211 kB 33.6 MB/s eta 0:00:01
# Collecting responses<0.19
#   Downloading responses-0.17.0-py2.py3-none-any.whl (38 kB)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 18.6 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.19.0 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from datasets) (2.25.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.12.2-py36-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 4.9 MB/s eta 0:00:01
# Collecting pyarrow>=5.0.0
#   Downloading pyarrow-6.0.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
#      |████████████████████████████████| 25.6 MB 20.2 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from datasets) (20.9)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
#      |████████████████████████████████| 603 kB 14.9 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.0)
# Requirement already satisfied: filelock in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (1.26.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (2021.5.30)
# Requirement already satisfied: six in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from responses<0.19->datasets) (1.16.0)
# Collecting importlib-resources
#   Downloading importlib_resources-5.4.0-py3-none-any.whl (28 kB)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (270 kB)
#      |████████████████████████████████| 270 kB 22.9 MB/s eta 0:00:01
# Collecting idna-ssl>=1.0
#   Downloading idna-ssl-1.1.0.tar.gz (3.4 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (159 kB)
#      |████████████████████████████████| 159 kB 6.3 MB/s eta 0:00:01
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from aiohttp->datasets) (21.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (191 kB)
#      |████████████████████████████████| 191 kB 7.7 MB/s eta 0:00:01
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Requirement already satisfied: zipp>=0.5 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from importlib-metadata->datasets) (3.4.1)
# Requirement already satisfied: pytz>=2017.2 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/david/anaconda3/envs/neurox-toolkit/lib/python3.6/site-packages (from pandas->datasets) (2.8.1)
# Building wheels for collected packages: idna-ssl
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-py3-none-any.whl size=3160 sha256=f44ab80faaf060f7593e393a973ff42d1067bd3b50acaed55dbfde24d865c2fc
#   Stored in directory: /home/david/.cache/pip/wheels/6a/f5/9c/f8331a854f7a8739cf0e74c13854e4dd7b1af11b04fe1dde13
# Successfully built idna-ssl
# Installing collected packages: multidict, frozenlist, yarl, importlib-resources, idna-ssl, charset-normalizer, asynctest, async-timeout, aiosignal, tqdm, pyyaml, fsspec, dill, aiohttp, xxhash, responses, pyarrow, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.61.0
#     Uninstalling tqdm-4.61.0:
#       Successfully uninstalled tqdm-4.61.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.0.8
#     Uninstalling huggingface-hub-0.0.8:
#       Successfully uninstalled huggingface-hub-0.0.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.6.1 requires huggingface-hub==0.0.8, but you have huggingface-hub 0.4.0 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 charset-normalizer-2.0.12 datasets-2.0.0 dill-0.3.4 frozenlist-1.2.0 fsspec-2022.1.0 huggingface-hub-0.4.0 idna-ssl-1.1.0 importlib-resources-5.4.0 multidict-5.2.0 multiprocess-0.70.12.2 pyarrow-6.0.1 pyyaml-6.0 responses-0.17.0 tqdm-4.63.0 xxhash-3.0.0 yarl-1.7.2

# %%
task = "pos" # Should be one of "ner", "pos" or "chunk"
from datasets import load_dataset

# %%
datasets = load_dataset("conll2003")
# Out:
# Reusing dataset conll2003 (/home/david/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/63f4ebd1bcb7148b1644497336fd74643d4ce70123334431a3c053b7ee4e96ee)
# 100%|██████████| 3/3 [00:00<00:00, 162.70it/s]

# %%
cutoff = 1000

# %%
# write the dataset tokens to file
for ds in ['train', 'validation', 'test']:
    with open(ds+'.tok', 'w') as f:
        for sent in datasets[ds]['tokens'][:cutoff]:
            f.write(' '.join(sent))
            f.write('\n')

# %%
# decode the pos tags from the dataset and write to file
for ds in ['train', 'validation', 'test']:
    with open(ds+'.pos', 'w') as f:
        for sent in datasets[ds]['pos_tags'][:cutoff]:
            f.write(' '.join([datasets[ds].features['pos_tags'].feature.names[t] for t in sent]))
            f.write('\n')

# %% [markdown]
# # Extract Representations

# %%
import neurox.data.extraction.transformers_extractor as transformers_extractor
transformers_extractor.extract_representations('distilbert-base-uncased',
    'train.tok',
    'train_activations.hdf5',
    aggregation="average", #last, first
    output_type='hdf5'
)
# Out:
# Loading model: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Reading input corpus
# Preparing output file
# Extracting representations from model
# Sentence         : "EU rejects German call to boycott British lamb ."
# Original    (009): ['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.']
# Tokenized   (011): ['[CLS]', 'eu', 'rejects', 'german', 'call', 'to', 'boycott', 'british', 'lamb', '.', '[SEP]']
# Filtered   (009): ['eu', 'rejects', 'german', 'call', 'to', 'boycott', 'british', 'lamb', '.']
# Detokenized (009): ['eu', 'rejects', 'german', 'call', 'to', 'boycott', 'british', 'lamb', '.']
# Counter: 9
# ===================================================================
# Hidden states:  (7, 9, 768)
# # Extracted words:  9
# Sentence         : "Peter Blackburn"
# Original    (002): ['Peter', 'Blackburn']
# Tokenized   (004): ['[CLS]', 'peter', 'blackburn', '[SEP]']
# Filtered   (002): ['peter', 'blackburn']
# Detokenized (002): ['peter', 'blackburn']
# Counter: 2
# ===================================================================
# Hidden states:  (7, 2, 768)
# # Extracted words:  2
# Sentence         : "BRUSSELS 1996-08-22"
# Original    (002): ['BRUSSELS', '1996-08-22']
# Tokenized   (008): ['[CLS]', 'brussels', '1996', '-', '08', '-', '22', '[SEP]']
# Filtered   (006): ['brussels', '1996', '-', '08', '-', '22']
# Detokenized (002): ['brussels', '1996-08-22']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 2, 768)
# # Extracted words:  2
# Sentence         : "The European Commission said on Thursday it disagreed with German advice to consumers to shun British lamb until scientists determine whether mad cow disease can be transmitted to sheep ."
# Original    (030): ['The', 'European', 'Commission', 'said', 'on', 'Thursday', 'it', 'disagreed', 'with', 'German', 'advice', 'to', 'consumers', 'to', 'shun', 'British', 'lamb', 'until', 'scientists', 'determine', 'whether', 'mad', 'cow', 'disease', 'can', 'be', 'transmitted', 'to', 'sheep', '.']
# Tokenized   (033): ['[CLS]', 'the', 'european', 'commission', 'said', 'on', 'thursday', 'it', 'disagreed', 'with', 'german', 'advice', 'to', 'consumers', 'to', 'shu', '##n', 'british', 'lamb', 'until', 'scientists', 'determine', 'whether', 'mad', 'cow', 'disease', 'can', 'be', 'transmitted', 'to', 'sheep', '.', '[SEP]']
# Filtered   (031): ['the', 'european', 'commission', 'said', 'on', 'thursday', 'it', 'disagreed', 'with', 'german', 'advice', 'to', 'consumers', 'to', 'shu', '##n', 'british', 'lamb', 'until', 'scientists', 'determine', 'whether', 'mad', 'cow', 'disease', 'can', 'be', 'transmitted', 'to', 'sheep', '.']
# Detokenized (030): ['the', 'european', 'commission', 'said', 'on', 'thursday', 'it', 'disagreed', 'with', 'german', 'advice', 'to', 'consumers', 'to', 'shu##n', 'british', 'lamb', 'until', 'scientists', 'determine', 'whether', 'mad', 'cow', 'disease', 'can', 'be', 'transmitted', 'to', 'sheep', '.']
# Counter: 31
# ===================================================================
# Hidden states:  (7, 30, 768)
# # Extracted words:  30
# Sentence         : "Germany 's representative to the European Union 's veterinary committee Werner Zwingmann said on Wednesday consumers should buy sheepmeat from countries other than Britain until the scientific advice was clearer ."
# Original    (031): ['Germany', "'s", 'representative', 'to', 'the', 'European', 'Union', "'s", 'veterinary', 'committee', 'Werner', 'Zwingmann', 'said', 'on', 'Wednesday', 'consumers', 'should', 'buy', 'sheepmeat', 'from', 'countries', 'other', 'than', 'Britain', 'until', 'the', 'scientific', 'advice', 'was', 'clearer', '.']
# Tokenized   (039): ['[CLS]', 'germany', "'", 's', 'representative', 'to', 'the', 'european', 'union', "'", 's', 'veterinary', 'committee', 'werner', 'z', '##wing', '##mann', 'said', 'on', 'wednesday', 'consumers', 'should', 'buy', 'sheep', '##me', '##at', 'from', 'countries', 'other', 'than', 'britain', 'until', 'the', 'scientific', 'advice', 'was', 'clearer', '.', '[SEP]']
# Filtered   (037): ['germany', "'", 's', 'representative', 'to', 'the', 'european', 'union', "'", 's', 'veterinary', 'committee', 'werner', 'z', '##wing', '##mann', 'said', 'on', 'wednesday', 'consumers', 'should', 'buy', 'sheep', '##me', '##at', 'from', 'countries', 'other', 'than', 'britain', 'until', 'the', 'scientific', 'advice', 'was', 'clearer', '.']
# Detokenized (031): ['germany', "'s", 'representative', 'to', 'the', 'european', 'union', "'s", 'veterinary', 'committee', 'werner', 'z##wing##mann', 'said', 'on', 'wednesday', 'consumers', 'should', 'buy', 'sheep##me##at', 'from', 'countries', 'other', 'than', 'britain', 'until', 'the', 'scientific', 'advice', 'was', 'clearer', '.']
# Counter: 37
# ===================================================================
# Hidden states:  (7, 31, 768)
# # Extracted words:  31
# Sentence         : "" We do n't support any such recommendation because we do n't see any grounds for it , " the Commission 's chief spokesman Nikolaus van der Pas told a news briefing ."
# Original    (033): ['"', 'We', 'do', "n't", 'support', 'any', 'such', 'recommendation', 'because', 'we', 'do', "n't", 'see', 'any', 'grounds', 'for', 'it', ',', '"', 'the', 'Commission', "'s", 'chief', 'spokesman', 'Nikolaus', 'van', 'der', 'Pas', 'told', 'a', 'news', 'briefing', '.']
# Tokenized   (041): ['[CLS]', '"', 'we', 'do', 'n', "'", 't', 'support', 'any', 'such', 'recommendation', 'because', 'we', 'do', 'n', "'", 't', 'see', 'any', 'grounds', 'for', 'it', ',', '"', 'the', 'commission', "'", 's', 'chief', 'spokesman', 'nikola', '##us', 'van', 'der', 'pas', 'told', 'a', 'news', 'briefing', '.', '[SEP]']
# Filtered   (039): ['"', 'we', 'do', 'n', "'", 't', 'support', 'any', 'such', 'recommendation', 'because', 'we', 'do', 'n', "'", 't', 'see', 'any', 'grounds', 'for', 'it', ',', '"', 'the', 'commission', "'", 's', 'chief', 'spokesman', 'nikola', '##us', 'van', 'der', 'pas', 'told', 'a', 'news', 'briefing', '.']
# Detokenized (033): ['"', 'we', 'do', "n't", 'support', 'any', 'such', 'recommendation', 'because', 'we', 'do', "n't", 'see', 'any', 'grounds', 'for', 'it', ',', '"', 'the', 'commission', "'s", 'chief', 'spokesman', 'nikola##us', 'van', 'der', 'pas', 'told', 'a', 'news', 'briefing', '.']
# Counter: 39
# ===================================================================
# Hidden states:  (7, 33, 768)
# # Extracted words:  33
# Sentence         : "He said further scientific study was required and if it was found that action was needed it should be taken by the European Union ."
# Original    (025): ['He', 'said', 'further', 'scientific', 'study', 'was', 'required', 'and', 'if', 'it', 'was', 'found', 'that', 'action', 'was', 'needed', 'it', 'should', 'be', 'taken', 'by', 'the', 'European', 'Union', '.']
# Tokenized   (027): ['[CLS]', 'he', 'said', 'further', 'scientific', 'study', 'was', 'required', 'and', 'if', 'it', 'was', 'found', 'that', 'action', 'was', 'needed', 'it', 'should', 'be', 'taken', 'by', 'the', 'european', 'union', '.', '[SEP]']
# Filtered   (025): ['he', 'said', 'further', 'scientific', 'study', 'was', 'required', 'and', 'if', 'it', 'was', 'found', 'that', 'action', 'was', 'needed', 'it', 'should', 'be', 'taken', 'by', 'the', 'european', 'union', '.']
# Detokenized (025): ['he', 'said', 'further', 'scientific', 'study', 'was', 'required', 'and', 'if', 'it', 'was', 'found', 'that', 'action', 'was', 'needed', 'it', 'should', 'be', 'taken', 'by', 'the', 'european', 'union', '.']
# Counter: 25
# ===================================================================
# Hidden states:  (7, 25, 768)
# # Extracted words:  25
# Sentence         : "He said a proposal last month by EU Farm Commissioner Franz Fischler to ban sheep brains , spleens and spinal cords from the human and animal food chains was a highly specific and precautionary move to protect human health ."
# Original    (040): ['He', 'said', 'a', 'proposal', 'last', 'month', 'by', 'EU', 'Farm', 'Commissioner', 'Franz', 'Fischler', 'to', 'ban', 'sheep', 'brains', ',', 'spleens', 'and', 'spinal', 'cords', 'from', 'the', 'human', 'and', 'animal', 'food', 'chains', 'was', 'a', 'highly', 'specific', 'and', 'precautionary', 'move', 'to', 'protect', 'human', 'health', '.']
# Tokenized   (049): ['[CLS]', 'he', 'said', 'a', 'proposal', 'last', 'month', 'by', 'eu', 'farm', 'commissioner', 'franz', 'fis', '##ch', '##ler', 'to', 'ban', 'sheep', 'brains', ',', 'sp', '##leen', '##s', 'and', 'spinal', 'cords', 'from', 'the', 'human', 'and', 'animal', 'food', 'chains', 'was', 'a', 'highly', 'specific', 'and', 'pre', '##ca', '##ution', '##ary', 'move', 'to', 'protect', 'human', 'health', '.', '[SEP]']
# Filtered   (047): ['he', 'said', 'a', 'proposal', 'last', 'month', 'by', 'eu', 'farm', 'commissioner', 'franz', 'fis', '##ch', '##ler', 'to', 'ban', 'sheep', 'brains', ',', 'sp', '##leen', '##s', 'and', 'spinal', 'cords', 'from', 'the', 'human', 'and', 'animal', 'food', 'chains', 'was', 'a', 'highly', 'specific', 'and', 'pre', '##ca', '##ution', '##ary', 'move', 'to', 'protect', 'human', 'health', '.']
# Detokenized (040): ['he', 'said', 'a', 'proposal', 'last', 'month', 'by', 'eu', 'farm', 'commissioner', 'franz', 'fis##ch##ler', 'to', 'ban', 'sheep', 'brains', ',', 'sp##leen##s', 'and', 'spinal', 'cords', 'from', 'the', 'human', 'and', 'animal', 'food', 'chains', 'was', 'a', 'highly', 'specific', 'and', 'pre##ca##ution##ary', 'move', 'to', 'protect', 'human', 'health', '.']
# Counter: 47
# ===================================================================
# Hidden states:  (7, 40, 768)
# # Extracted words:  40
# Sentence         : "Fischler proposed EU-wide measures after reports from Britain and France that under laboratory conditions sheep could contract Bovine Spongiform Encephalopathy ( BSE ) -- mad cow disease ."
# Original    (028): ['Fischler', 'proposed', 'EU-wide', 'measures', 'after', 'reports', 'from', 'Britain', 'and', 'France', 'that', 'under', 'laboratory', 'conditions', 'sheep', 'could', 'contract', 'Bovine', 'Spongiform', 'Encephalopathy', '(', 'BSE', ')', '--', 'mad', 'cow', 'disease', '.']
# Tokenized   (043): ['[CLS]', 'fis', '##ch', '##ler', 'proposed', 'eu', '-', 'wide', 'measures', 'after', 'reports', 'from', 'britain', 'and', 'france', 'that', 'under', 'laboratory', 'conditions', 'sheep', 'could', 'contract', 'bo', '##vine', 'sp', '##ong', '##iform', 'en', '##ce', '##pha', '##lo', '##pathy', '(', 'bs', '##e', ')', '-', '-', 'mad', 'cow', 'disease', '.', '[SEP]']
# Filtered   (041): ['fis', '##ch', '##ler', 'proposed', 'eu', '-', 'wide', 'measures', 'after', 'reports', 'from', 'britain', 'and', 'france', 'that', 'under', 'laboratory', 'conditions', 'sheep', 'could', 'contract', 'bo', '##vine', 'sp', '##ong', '##iform', 'en', '##ce', '##pha', '##lo', '##pathy', '(', 'bs', '##e', ')', '-', '-', 'mad', 'cow', 'disease', '.']
# Detokenized (028): ['fis##ch##ler', 'proposed', 'eu-wide', 'measures', 'after', 'reports', 'from', 'britain', 'and', 'france', 'that', 'under', 'laboratory', 'conditions', 'sheep', 'could', 'contract', 'bo##vine', 'sp##ong##iform', 'en##ce##pha##lo##pathy', '(', 'bs##e', ')', '--', 'mad', 'cow', 'disease', '.']
# Counter: 41
# ===================================================================
# Hidden states:  (7, 28, 768)
# # Extracted words:  28
# Sentence         : "But Fischler agreed to review his proposal after the EU 's standing veterinary committee , mational animal health officials , questioned if such action was justified as there was only a slight risk to human health ."
# Original    (037): ['But', 'Fischler', 'agreed', 'to', 'review', 'his', 'proposal', 'after', 'the', 'EU', "'s", 'standing', 'veterinary', 'committee', ',', 'mational', 'animal', 'health', 'officials', ',', 'questioned', 'if', 'such', 'action', 'was', 'justified', 'as', 'there', 'was', 'only', 'a', 'slight', 'risk', 'to', 'human', 'health', '.']
# Tokenized   (043): ['[CLS]', 'but', 'fis', '##ch', '##ler', 'agreed', 'to', 'review', 'his', 'proposal', 'after', 'the', 'eu', "'", 's', 'standing', 'veterinary', 'committee', ',', 'mat', '##ional', 'animal', 'health', 'officials', ',', 'questioned', 'if', 'such', 'action', 'was', 'justified', 'as', 'there', 'was', 'only', 'a', 'slight', 'risk', 'to', 'human', 'health', '.', '[SEP]']
# Filtered   (041): ['but', 'fis', '##ch', '##ler', 'agreed', 'to', 'review', 'his', 'proposal', 'after', 'the', 'eu', "'", 's', 'standing', 'veterinary', 'committee', ',', 'mat', '##ional', 'animal', 'health', 'officials', ',', 'questioned', 'if', 'such', 'action', 'was', 'justified', 'as', 'there', 'was', 'only', 'a', 'slight', 'risk', 'to', 'human', 'health', '.']
# Detokenized (037): ['but', 'fis##ch##ler', 'agreed', 'to', 'review', 'his', 'proposal', 'after', 'the', 'eu', "'s", 'standing', 'veterinary', 'committee', ',', 'mat##ional', 'animal', 'health', 'officials', ',', 'questioned', 'if', 'such', 'action', 'was', 'justified', 'as', 'there', 'was', 'only', 'a', 'slight', 'risk', 'to', 'human', 'health', '.']
# Counter: 41
# ===================================================================
# Hidden states:  (7, 37, 768)
# # Extracted words:  37
# Sentence         : "Spanish Farm Minister Loyola de Palacio had earlier accused Fischler at an EU farm ministers ' meeting of causing unjustified alarm through " dangerous generalisation . ""
# Original    (027): ['Spanish', 'Farm', 'Minister', 'Loyola', 'de', 'Palacio', 'had', 'earlier', 'accused', 'Fischler', 'at', 'an', 'EU', 'farm', 'ministers', "'", 'meeting', 'of', 'causing', 'unjustified', 'alarm', 'through', '"', 'dangerous', 'generalisation', '.', '"']
# Tokenized   (035): ['[CLS]', 'spanish', 'farm', 'minister', 'loyola', 'de', 'pal', '##acio', 'had', 'earlier', 'accused', 'fis', '##ch', '##ler', 'at', 'an', 'eu', 'farm', 'ministers', "'", 'meeting', 'of', 'causing', 'un', '##just', '##ified', 'alarm', 'through', '"', 'dangerous', 'general', '##isation', '.', '"', '[SEP]']
# Filtered   (033): ['spanish', 'farm', 'minister', 'loyola', 'de', 'pal', '##acio', 'had', 'earlier', 'accused', 'fis', '##ch', '##ler', 'at', 'an', 'eu', 'farm', 'ministers', "'", 'meeting', 'of', 'causing', 'un', '##just', '##ified', 'alarm', 'through', '"', 'dangerous', 'general', '##isation', '.', '"']
# Detokenized (027): ['spanish', 'farm', 'minister', 'loyola', 'de', 'pal##acio', 'had', 'earlier', 'accused', 'fis##ch##ler', 'at', 'an', 'eu', 'farm', 'ministers', "'", 'meeting', 'of', 'causing', 'un##just##ified', 'alarm', 'through', '"', 'dangerous', 'general##isation', '.', '"']
# Counter: 33
# ===================================================================
# Hidden states:  (7, 27, 768)
# # Extracted words:  27
# Sentence         : "."
# Original    (001): ['.']
# Tokenized   (003): ['[CLS]', '.', '[SEP]']
# Filtered   (001): ['.']
# Detokenized (001): ['.']
# Counter: 1
# ===================================================================
# Hidden states:  (7, 1, 768)
# # Extracted words:  1
# Sentence         : "Only France and Britain backed Fischler 's proposal ."
# Original    (009): ['Only', 'France', 'and', 'Britain', 'backed', 'Fischler', "'s", 'proposal', '.']
# Tokenized   (014): ['[CLS]', 'only', 'france', 'and', 'britain', 'backed', 'fis', '##ch', '##ler', "'", 's', 'proposal', '.', '[SEP]']
# Filtered   (012): ['only', 'france', 'and', 'britain', 'backed', 'fis', '##ch', '##ler', "'", 's', 'proposal', '.']
# Detokenized (009): ['only', 'france', 'and', 'britain', 'backed', 'fis##ch##ler', "'s", 'proposal', '.']
# Counter: 12
# ===================================================================
# Hidden states:  (7, 9, 768)
# # Extracted words:  9
# Sentence         : "The EU 's scientific veterinary and multidisciplinary committees are due to re-examine the issue early next month and make recommendations to the senior veterinary officials ."
# Original    (026): ['The', 'EU', "'s", 'scientific', 'veterinary', 'and', 'multidisciplinary', 'committees', 'are', 'due', 'to', 're-examine', 'the', 'issue', 'early', 'next', 'month', 'and', 'make', 'recommendations', 'to', 'the', 'senior', 'veterinary', 'officials', '.']
# Tokenized   (035): ['[CLS]', 'the', 'eu', "'", 's', 'scientific', 'veterinary', 'and', 'multi', '##dis', '##ci', '##plin', '##ary', 'committees', 'are', 'due', 'to', 're', '-', 'examine', 'the', 'issue', 'early', 'next', 'month', 'and', 'make', 'recommendations', 'to', 'the', 'senior', 'veterinary', 'officials', '.', '[SEP]']
# Filtered   (033): ['the', 'eu', "'", 's', 'scientific', 'veterinary', 'and', 'multi', '##dis', '##ci', '##plin', '##ary', 'committees', 'are', 'due', 'to', 're', '-', 'examine', 'the', 'issue', 'early', 'next', 'month', 'and', 'make', 'recommendations', 'to', 'the', 'senior', 'veterinary', 'officials', '.']
# Detokenized (026): ['the', 'eu', "'s", 'scientific', 'veterinary', 'and', 'multi##dis##ci##plin##ary', 'committees', 'are', 'due', 'to', 're-examine', 'the', 'issue', 'early', 'next', 'month', 'and', 'make', 'recommendations', 'to', 'the', 'senior', 'veterinary', 'officials', '.']
# Counter: 33
# ===================================================================
# Hidden states:  (7, 26, 768)
# # Extracted words:  26
# Sentence         : "Sheep have long been known to contract scrapie , a brain-wasting disease similar to BSE which is believed to have been transferred to cattle through feed containing animal waste ."
# Original    (030): ['Sheep', 'have', 'long', 'been', 'known', 'to', 'contract', 'scrapie', ',', 'a', 'brain-wasting', 'disease', 'similar', 'to', 'BSE', 'which', 'is', 'believed', 'to', 'have', 'been', 'transferred', 'to', 'cattle', 'through', 'feed', 'containing', 'animal', 'waste', '.']
# Tokenized   (036): ['[CLS]', 'sheep', 'have', 'long', 'been', 'known', 'to', 'contract', 'scrap', '##ie', ',', 'a', 'brain', '-', 'wasting', 'disease', 'similar', 'to', 'bs', '##e', 'which', 'is', 'believed', 'to', 'have', 'been', 'transferred', 'to', 'cattle', 'through', 'feed', 'containing', 'animal', 'waste', '.', '[SEP]']
# Filtered   (034): ['sheep', 'have', 'long', 'been', 'known', 'to', 'contract', 'scrap', '##ie', ',', 'a', 'brain', '-', 'wasting', 'disease', 'similar', 'to', 'bs', '##e', 'which', 'is', 'believed', 'to', 'have', 'been', 'transferred', 'to', 'cattle', 'through', 'feed', 'containing', 'animal', 'waste', '.']
# Detokenized (030): ['sheep', 'have', 'long', 'been', 'known', 'to', 'contract', 'scrap##ie', ',', 'a', 'brain-wasting', 'disease', 'similar', 'to', 'bs##e', 'which', 'is', 'believed', 'to', 'have', 'been', 'transferred', 'to', 'cattle', 'through', 'feed', 'containing', 'animal', 'waste', '.']
# Counter: 34
# ===================================================================
# Hidden states:  (7, 30, 768)
# # Extracted words:  30
# Sentence         : "British farmers denied on Thursday there was any danger to human health from their sheep , but expressed concern that German government advice to consumers to avoid British lamb might influence consumers across Europe ."
# Original    (035): ['British', 'farmers', 'denied', 'on', 'Thursday', 'there', 'was', 'any', 'danger', 'to', 'human', 'health', 'from', 'their', 'sheep', ',', 'but', 'expressed', 'concern', 'that', 'German', 'government', 'advice', 'to', 'consumers', 'to', 'avoid', 'British', 'lamb', 'might', 'influence', 'consumers', 'across', 'Europe', '.']
# Tokenized   (037): ['[CLS]', 'british', 'farmers', 'denied', 'on', 'thursday', 'there', 'was', 'any', 'danger', 'to', 'human', 'health', 'from', 'their', 'sheep', ',', 'but', 'expressed', 'concern', 'that', 'german', 'government', 'advice', 'to', 'consumers', 'to', 'avoid', 'british', 'lamb', 'might', 'influence', 'consumers', 'across', 'europe', '.', '[SEP]']
# Filtered   (035): ['british', 'farmers', 'denied', 'on', 'thursday', 'there', 'was', 'any', 'danger', 'to', 'human', 'health', 'from', 'their', 'sheep', ',', 'but', 'expressed', 'concern', 'that', 'german', 'government', 'advice', 'to', 'consumers', 'to', 'avoid', 'british', 'lamb', 'might', 'influence', 'consumers', 'across', 'europe', '.']
# Detokenized (035): ['british', 'farmers', 'denied', 'on', 'thursday', 'there', 'was', 'any', 'danger', 'to', 'human', 'health', 'from', 'their', 'sheep', ',', 'but', 'expressed', 'concern', 'that', 'german', 'government', 'advice', 'to', 'consumers', 'to', 'avoid', 'british', 'lamb', 'might', 'influence', 'consumers', 'across', 'europe', '.']
# Counter: 35
# ===================================================================
# Hidden states:  (7, 35, 768)
# # Extracted words:  35
# Sentence         : "" What we have to be extremely careful of is how other countries are going to take Germany 's lead , " Welsh National Farmers ' Union ( NFU ) chairman John Lloyd Jones said on BBC radio ."
# Original    (039): ['"', 'What', 'we', 'have', 'to', 'be', 'extremely', 'careful', 'of', 'is', 'how', 'other', 'countries', 'are', 'going', 'to', 'take', 'Germany', "'s", 'lead', ',', '"', 'Welsh', 'National', 'Farmers', "'", 'Union', '(', 'NFU', ')', 'chairman', 'John', 'Lloyd', 'Jones', 'said', 'on', 'BBC', 'radio', '.']
# Tokenized   (043): ['[CLS]', '"', 'what', 'we', 'have', 'to', 'be', 'extremely', 'careful', 'of', 'is', 'how', 'other', 'countries', 'are', 'going', 'to', 'take', 'germany', "'", 's', 'lead', ',', '"', 'welsh', 'national', 'farmers', "'", 'union', '(', 'n', '##fu', ')', 'chairman', 'john', 'lloyd', 'jones', 'said', 'on', 'bbc', 'radio', '.', '[SEP]']
# Filtered   (041): ['"', 'what', 'we', 'have', 'to', 'be', 'extremely', 'careful', 'of', 'is', 'how', 'other', 'countries', 'are', 'going', 'to', 'take', 'germany', "'", 's', 'lead', ',', '"', 'welsh', 'national', 'farmers', "'", 'union', '(', 'n', '##fu', ')', 'chairman', 'john', 'lloyd', 'jones', 'said', 'on', 'bbc', 'radio', '.']
# Detokenized (039): ['"', 'what', 'we', 'have', 'to', 'be', 'extremely', 'careful', 'of', 'is', 'how', 'other', 'countries', 'are', 'going', 'to', 'take', 'germany', "'s", 'lead', ',', '"', 'welsh', 'national', 'farmers', "'", 'union', '(', 'n##fu', ')', 'chairman', 'john', 'lloyd', 'jones', 'said', 'on', 'bbc', 'radio', '.']
# Counter: 41
# ===================================================================
# Hidden states:  (7, 39, 768)
# # Extracted words:  39
# Sentence         : "Bonn has led efforts to protect public health after consumer confidence collapsed in March after a British report suggested humans could contract an illness similar to mad cow disease by eating contaminated beef ."
# Original    (034): ['Bonn', 'has', 'led', 'efforts', 'to', 'protect', 'public', 'health', 'after', 'consumer', 'confidence', 'collapsed', 'in', 'March', 'after', 'a', 'British', 'report', 'suggested', 'humans', 'could', 'contract', 'an', 'illness', 'similar', 'to', 'mad', 'cow', 'disease', 'by', 'eating', 'contaminated', 'beef', '.']
# Tokenized   (036): ['[CLS]', 'bonn', 'has', 'led', 'efforts', 'to', 'protect', 'public', 'health', 'after', 'consumer', 'confidence', 'collapsed', 'in', 'march', 'after', 'a', 'british', 'report', 'suggested', 'humans', 'could', 'contract', 'an', 'illness', 'similar', 'to', 'mad', 'cow', 'disease', 'by', 'eating', 'contaminated', 'beef', '.', '[SEP]']
# Filtered   (034): ['bonn', 'has', 'led', 'efforts', 'to', 'protect', 'public', 'health', 'after', 'consumer', 'confidence', 'collapsed', 'in', 'march', 'after', 'a', 'british', 'report', 'suggested', 'humans', 'could', 'contract', 'an', 'illness', 'similar', 'to', 'mad', 'cow', 'disease', 'by', 'eating', 'contaminated', 'beef', '.']
# Detokenized (034): ['bonn', 'has', 'led', 'efforts', 'to', 'protect', 'public', 'health', 'after', 'consumer', 'confidence', 'collapsed', 'in', 'march', 'after', 'a', 'british', 'report', 'suggested', 'humans', 'could', 'contract', 'an', 'illness', 'similar', 'to', 'mad', 'cow', 'disease', 'by', 'eating', 'contaminated', 'beef', '.']
# Counter: 34
# ===================================================================
# Hidden states:  (7, 34, 768)
# # Extracted words:  34
# Sentence         : "Germany imported 47,600 sheep from Britain last year , nearly half of total imports ."
# Original    (015): ['Germany', 'imported', '47,600', 'sheep', 'from', 'Britain', 'last', 'year', ',', 'nearly', 'half', 'of', 'total', 'imports', '.']
# Tokenized   (019): ['[CLS]', 'germany', 'imported', '47', ',', '600', 'sheep', 'from', 'britain', 'last', 'year', ',', 'nearly', 'half', 'of', 'total', 'imports', '.', '[SEP]']
# Filtered   (017): ['germany', 'imported', '47', ',', '600', 'sheep', 'from', 'britain', 'last', 'year', ',', 'nearly', 'half', 'of', 'total', 'imports', '.']
# Detokenized (015): ['germany', 'imported', '47,600', 'sheep', 'from', 'britain', 'last', 'year', ',', 'nearly', 'half', 'of', 'total', 'imports', '.']
# Counter: 17
# ===================================================================
# Hidden states:  (7, 15, 768)
# # Extracted words:  15
# Sentence         : "It brought in 4,275 tonnes of British mutton , some 10 percent of overall imports ."
# Original    (016): ['It', 'brought', 'in', '4,275', 'tonnes', 'of', 'British', 'mutton', ',', 'some', '10', 'percent', 'of', 'overall', 'imports', '.']
# Tokenized   (021): ['[CLS]', 'it', 'brought', 'in', '4', ',', '275', 'tonnes', 'of', 'british', 'mu', '##tton', ',', 'some', '10', 'percent', 'of', 'overall', 'imports', '.', '[SEP]']
# Filtered   (019): ['it', 'brought', 'in', '4', ',', '275', 'tonnes', 'of', 'british', 'mu', '##tton', ',', 'some', '10', 'percent', 'of', 'overall', 'imports', '.']
# Detokenized (016): ['it', 'brought', 'in', '4,275', 'tonnes', 'of', 'british', 'mu##tton', ',', 'some', '10', 'percent', 'of', 'overall', 'imports', '.']
# Counter: 19
# ===================================================================
# Hidden states:  (7, 16, 768)
# # Extracted words:  16
# Sentence         : "Rare Hendrix song draft sells for almost $ 17,000 ."
# Original    (010): ['Rare', 'Hendrix', 'song', 'draft', 'sells', 'for', 'almost', '$', '17,000', '.']
# Tokenized   (014): ['[CLS]', 'rare', 'hendrix', 'song', 'draft', 'sells', 'for', 'almost', '$', '17', ',', '000', '.', '[SEP]']
# Filtered   (012): ['rare', 'hendrix', 'song', 'draft', 'sells', 'for', 'almost', '$', '17', ',', '000', '.']
# Detokenized (010): ['rare', 'hendrix', 'song', 'draft', 'sells', 'for', 'almost', '$', '17,000', '.']
# Counter: 12
# ===================================================================
# Hidden states:  (7, 10, 768)
# # Extracted words:  10
# Sentence         : "LONDON 1996-08-22"
# Original    (002): ['LONDON', '1996-08-22']
# Tokenized   (008): ['[CLS]', 'london', '1996', '-', '08', '-', '22', '[SEP]']
# Filtered   (006): ['london', '1996', '-', '08', '-', '22']
# Detokenized (002): ['london', '1996-08-22']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 2, 768)
# # Extracted words:  2
# Sentence         : "A rare early handwritten draft of a song by U.S. guitar legend Jimi Hendrix was sold for almost $ 17,000 on Thursday at an auction of some of the late musician 's favourite possessions ."
# Original    (035): ['A', 'rare', 'early', 'handwritten', 'draft', 'of', 'a', 'song', 'by', 'U.S.', 'guitar', 'legend', 'Jimi', 'Hendrix', 'was', 'sold', 'for', 'almost', '$', '17,000', 'on', 'Thursday', 'at', 'an', 'auction', 'of', 'some', 'of', 'the', 'late', 'musician', "'s", 'favourite', 'possessions', '.']
# Tokenized   (044): ['[CLS]', 'a', 'rare', 'early', 'hand', '##written', 'draft', 'of', 'a', 'song', 'by', 'u', '.', 's', '.', 'guitar', 'legend', 'jimi', 'hendrix', 'was', 'sold', 'for', 'almost', '$', '17', ',', '000', 'on', 'thursday', 'at', 'an', 'auction', 'of', 'some', 'of', 'the', 'late', 'musician', "'", 's', 'favourite', 'possessions', '.', '[SEP]']
# Filtered   (042): ['a', 'rare', 'early', 'hand', '##written', 'draft', 'of', 'a', 'song', 'by', 'u', '.', 's', '.', 'guitar', 'legend', 'jimi', 'hendrix', 'was', 'sold', 'for', 'almost', '$', '17', ',', '000', 'on', 'thursday', 'at', 'an', 'auction', 'of', 'some', 'of', 'the', 'late', 'musician', "'", 's', 'favourite', 'possessions', '.']
# Detokenized (035): ['a', 'rare', 'early', 'hand##written', 'draft', 'of', 'a', 'song', 'by', 'u.s.', 'guitar', 'legend', 'jimi', 'hendrix', 'was', 'sold', 'for', 'almost', '$', '17,000', 'on', 'thursday', 'at', 'an', 'auction', 'of', 'some', 'of', 'the', 'late', 'musician', "'s", 'favourite', 'possessions', '.']
# Counter: 42
# ===================================================================
# Hidden states:  (7, 35, 768)
# # Extracted words:  35
# Sentence         : "A Florida restaurant paid 10,925 pounds ( $ 16,935 ) for the draft of " Ai n't no telling " , which Hendrix penned on a piece of London hotel stationery in late 1966 ."
# Original    (035): ['A', 'Florida', 'restaurant', 'paid', '10,925', 'pounds', '(', '$', '16,935', ')', 'for', 'the', 'draft', 'of', '"', 'Ai', "n't", 'no', 'telling', '"', ',', 'which', 'Hendrix', 'penned', 'on', 'a', 'piece', 'of', 'London', 'hotel', 'stationery', 'in', 'late', '1966', '.']
# Tokenized   (046): ['[CLS]', 'a', 'florida', 'restaurant', 'paid', '10', ',', '92', '##5', 'pounds', '(', '$', '16', ',', '93', '##5', ')', 'for', 'the', 'draft', 'of', '"', 'ai', 'n', "'", 't', 'no', 'telling', '"', ',', 'which', 'hendrix', 'penned', 'on', 'a', 'piece', 'of', 'london', 'hotel', 'station', '##ery', 'in', 'late', '1966', '.', '[SEP]']
# Filtered   (044): ['a', 'florida', 'restaurant', 'paid', '10', ',', '92', '##5', 'pounds', '(', '$', '16', ',', '93', '##5', ')', 'for', 'the', 'draft', 'of', '"', 'ai', 'n', "'", 't', 'no', 'telling', '"', ',', 'which', 'hendrix', 'penned', 'on', 'a', 'piece', 'of', 'london', 'hotel', 'station', '##ery', 'in', 'late', '1966', '.']
# Detokenized (035): ['a', 'florida', 'restaurant', 'paid', '10,92##5', 'pounds', '(', '$', '16,93##5', ')', 'for', 'the', 'draft', 'of', '"', 'ai', "n't", 'no', 'telling', '"', ',', 'which', 'hendrix', 'penned', 'on', 'a', 'piece', 'of', 'london', 'hotel', 'station##ery', 'in', 'late', '1966', '.']
# Counter: 44
# ===================================================================
# Hidden states:  (7, 35, 768)
# # Extracted words:  35
# Sentence         : "At the end of a January 1967 concert in the English city of Nottingham he threw the sheet of paper into the audience , where it was retrieved by a fan ."
# Original    (032): ['At', 'the', 'end', 'of', 'a', 'January', '1967', 'concert', 'in', 'the', 'English', 'city', 'of', 'Nottingham', 'he', 'threw', 'the', 'sheet', 'of', 'paper', 'into', 'the', 'audience', ',', 'where', 'it', 'was', 'retrieved', 'by', 'a', 'fan', '.']
# Tokenized   (034): ['[CLS]', 'at', 'the', 'end', 'of', 'a', 'january', '1967', 'concert', 'in', 'the', 'english', 'city', 'of', 'nottingham', 'he', 'threw', 'the', 'sheet', 'of', 'paper', 'into', 'the', 'audience', ',', 'where', 'it', 'was', 'retrieved', 'by', 'a', 'fan', '.', '[SEP]']
# Filtered   (032): ['at', 'the', 'end', 'of', 'a', 'january', '1967', 'concert', 'in', 'the', 'english', 'city', 'of', 'nottingham', 'he', 'threw', 'the', 'sheet', 'of', 'paper', 'into', 'the', 'audience', ',', 'where', 'it', 'was', 'retrieved', 'by', 'a', 'fan', '.']
# Detokenized (032): ['at', 'the', 'end', 'of', 'a', 'january', '1967', 'concert', 'in', 'the', 'english', 'city', 'of', 'nottingham', 'he', 'threw', 'the', 'sheet', 'of', 'paper', 'into', 'the', 'audience', ',', 'where', 'it', 'was', 'retrieved', 'by', 'a', 'fan', '.']
# Counter: 32
# ===================================================================
# Hidden states:  (7, 32, 768)
# # Extracted words:  32
# Sentence         : "Buyers also snapped up 16 other items that were put up for auction by Hendrix 's former girlfriend Kathy Etchingham , who lived with him from 1966 to 1969 ."
# Original    (030): ['Buyers', 'also', 'snapped', 'up', '16', 'other', 'items', 'that', 'were', 'put', 'up', 'for', 'auction', 'by', 'Hendrix', "'s", 'former', 'girlfriend', 'Kathy', 'Etchingham', ',', 'who', 'lived', 'with', 'him', 'from', '1966', 'to', '1969', '.']
# Tokenized   (035): ['[CLS]', 'buyers', 'also', 'snapped', 'up', '16', 'other', 'items', 'that', 'were', 'put', 'up', 'for', 'auction', 'by', 'hendrix', "'", 's', 'former', 'girlfriend', 'kathy', 'etc', '##hing', '##ham', ',', 'who', 'lived', 'with', 'him', 'from', '1966', 'to', '1969', '.', '[SEP]']
# Filtered   (033): ['buyers', 'also', 'snapped', 'up', '16', 'other', 'items', 'that', 'were', 'put', 'up', 'for', 'auction', 'by', 'hendrix', "'", 's', 'former', 'girlfriend', 'kathy', 'etc', '##hing', '##ham', ',', 'who', 'lived', 'with', 'him', 'from', '1966', 'to', '1969', '.']
# Detokenized (030): ['buyers', 'also', 'snapped', 'up', '16', 'other', 'items', 'that', 'were', 'put', 'up', 'for', 'auction', 'by', 'hendrix', "'s", 'former', 'girlfriend', 'kathy', 'etc##hing##ham', ',', 'who', 'lived', 'with', 'him', 'from', '1966', 'to', '1969', '.']
# Counter: 33
# ===================================================================
# Hidden states:  (7, 30, 768)
# # Extracted words:  30
# Sentence         : "They included a black lacquer and mother of pearl inlaid box used by Hendrix to store his drugs , which an anonymous Australian purchaser bought for 5,060 pounds ( $ 7,845 ) ."
# Original    (033): ['They', 'included', 'a', 'black', 'lacquer', 'and', 'mother', 'of', 'pearl', 'inlaid', 'box', 'used', 'by', 'Hendrix', 'to', 'store', 'his', 'drugs', ',', 'which', 'an', 'anonymous', 'Australian', 'purchaser', 'bought', 'for', '5,060', 'pounds', '(', '$', '7,845', ')', '.']
# Tokenized   (045): ['[CLS]', 'they', 'included', 'a', 'black', 'lac', '##que', '##r', 'and', 'mother', 'of', 'pearl', 'in', '##laid', 'box', 'used', 'by', 'hendrix', 'to', 'store', 'his', 'drugs', ',', 'which', 'an', 'anonymous', 'australian', 'purchase', '##r', 'bought', 'for', '5', ',', '06', '##0', 'pounds', '(', '$', '7', ',', '84', '##5', ')', '.', '[SEP]']
# Filtered   (043): ['they', 'included', 'a', 'black', 'lac', '##que', '##r', 'and', 'mother', 'of', 'pearl', 'in', '##laid', 'box', 'used', 'by', 'hendrix', 'to', 'store', 'his', 'drugs', ',', 'which', 'an', 'anonymous', 'australian', 'purchase', '##r', 'bought', 'for', '5', ',', '06', '##0', 'pounds', '(', '$', '7', ',', '84', '##5', ')', '.']
# Detokenized (033): ['they', 'included', 'a', 'black', 'lac##que##r', 'and', 'mother', 'of', 'pearl', 'in##laid', 'box', 'used', 'by', 'hendrix', 'to', 'store', 'his', 'drugs', ',', 'which', 'an', 'anonymous', 'australian', 'purchase##r', 'bought', 'for', '5,06##0', 'pounds', '(', '$', '7,84##5', ')', '.']
# Counter: 43
# ===================================================================
# Hidden states:  (7, 33, 768)
# # Extracted words:  33
# Sentence         : "The guitarist died of a drugs overdose in 1970 aged 27 ."
# Original    (012): ['The', 'guitarist', 'died', 'of', 'a', 'drugs', 'overdose', 'in', '1970', 'aged', '27', '.']
# Tokenized   (014): ['[CLS]', 'the', 'guitarist', 'died', 'of', 'a', 'drugs', 'overdose', 'in', '1970', 'aged', '27', '.', '[SEP]']
# Filtered   (012): ['the', 'guitarist', 'died', 'of', 'a', 'drugs', 'overdose', 'in', '1970', 'aged', '27', '.']
# Detokenized (012): ['the', 'guitarist', 'died', 'of', 'a', 'drugs', 'overdose', 'in', '1970', 'aged', '27', '.']
# Counter: 12
# ===================================================================
# Hidden states:  (7, 12, 768)
# # Extracted words:  12
# Sentence         : "China says Taiwan spoils atmosphere for talks ."
# Original    (008): ['China', 'says', 'Taiwan', 'spoils', 'atmosphere', 'for', 'talks', '.']
# Tokenized   (011): ['[CLS]', 'china', 'says', 'taiwan', 'spoil', '##s', 'atmosphere', 'for', 'talks', '.', '[SEP]']
# Filtered   (009): ['china', 'says', 'taiwan', 'spoil', '##s', 'atmosphere', 'for', 'talks', '.']
# Detokenized (008): ['china', 'says', 'taiwan', 'spoil##s', 'atmosphere', 'for', 'talks', '.']
# Counter: 9
# ===================================================================
# Hidden states:  (7, 8, 768)
# # Extracted words:  8
# Sentence         : "BEIJING 1996-08-22"
# Original    (002): ['BEIJING', '1996-08-22']
# Tokenized   (008): ['[CLS]', 'beijing', '1996', '-', '08', '-', '22', '[SEP]']
# Filtered   (006): ['beijing', '1996', '-', '08', '-', '22']
# Detokenized (002): ['beijing', '1996-08-22']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 2, 768)
# # Extracted words:  2
# Sentence         : "China on Thursday accused Taipei of spoiling the atmosphere for a resumption of talks across the Taiwan Strait with a visit to Ukraine by Taiwanese Vice President Lien Chan this week that infuriated Beijing ."
# Original    (035): ['China', 'on', 'Thursday', 'accused', 'Taipei', 'of', 'spoiling', 'the', 'atmosphere', 'for', 'a', 'resumption', 'of', 'talks', 'across', 'the', 'Taiwan', 'Strait', 'with', 'a', 'visit', 'to', 'Ukraine', 'by', 'Taiwanese', 'Vice', 'President', 'Lien', 'Chan', 'this', 'week', 'that', 'infuriated', 'Beijing', '.']
# Tokenized   (043): ['[CLS]', 'china', 'on', 'thursday', 'accused', 'taipei', 'of', 'spoil', '##ing', 'the', 'atmosphere', 'for', 'a', 'res', '##ump', '##tion', 'of', 'talks', 'across', 'the', 'taiwan', 'strait', 'with', 'a', 'visit', 'to', 'ukraine', 'by', 'taiwanese', 'vice', 'president', 'lie', '##n', 'chan', 'this', 'week', 'that', 'in', '##fur', '##iated', 'beijing', '.', '[SEP]']
# Filtered   (041): ['china', 'on', 'thursday', 'accused', 'taipei', 'of', 'spoil', '##ing', 'the', 'atmosphere', 'for', 'a', 'res', '##ump', '##tion', 'of', 'talks', 'across', 'the', 'taiwan', 'strait', 'with', 'a', 'visit', 'to', 'ukraine', 'by', 'taiwanese', 'vice', 'president', 'lie', '##n', 'chan', 'this', 'week', 'that', 'in', '##fur', '##iated', 'beijing', '.']
# Detokenized (035): ['china', 'on', 'thursday', 'accused', 'taipei', 'of', 'spoil##ing', 'the', 'atmosphere', 'for', 'a', 'res##ump##tion', 'of', 'talks', 'across', 'the', 'taiwan', 'strait', 'with', 'a', 'visit', 'to', 'ukraine', 'by', 'taiwanese', 'vice', 'president', 'lie##n', 'chan', 'this', 'week', 'that', 'in##fur##iated', 'beijing', '.']
# Counter: 41
# ===================================================================
# Hidden states:  (7, 35, 768)
# # Extracted words:  35
# Sentence         : "Speaking only hours after Chinese state media said the time was right to engage in political talks with Taiwan , Foreign Ministry spokesman Shen Guofang told Reuters : " The necessary atmosphere for the opening of the talks has been disrupted by the Taiwan authorities . ""
# Original    (047): ['Speaking', 'only', 'hours', 'after', 'Chinese', 'state', 'media', 'said', 'the', 'time', 'was', 'right', 'to', 'engage', 'in', 'political', 'talks', 'with', 'Taiwan', ',', 'Foreign', 'Ministry', 'spokesman', 'Shen', 'Guofang', 'told', 'Reuters', ':', '"', 'The', 'necessary', 'atmosphere', 'for', 'the', 'opening', 'of', 'the', 'talks', 'has', 'been', 'disrupted', 'by', 'the', 'Taiwan', 'authorities', '.', '"']
# Tokenized   (051): ['[CLS]', 'speaking', 'only', 'hours', 'after', 'chinese', 'state', 'media', 'said', 'the', 'time', 'was', 'right', 'to', 'engage', 'in', 'political', 'talks', 'with', 'taiwan', ',', 'foreign', 'ministry', 'spokesman', 'shen', 'guo', '##fan', '##g', 'told', 'reuters', ':', '"', 'the', 'necessary', 'atmosphere', 'for', 'the', 'opening', 'of', 'the', 'talks', 'has', 'been', 'disrupted', 'by', 'the', 'taiwan', 'authorities', '.', '"', '[SEP]']
# Filtered   (049): ['speaking', 'only', 'hours', 'after', 'chinese', 'state', 'media', 'said', 'the', 'time', 'was', 'right', 'to', 'engage', 'in', 'political', 'talks', 'with', 'taiwan', ',', 'foreign', 'ministry', 'spokesman', 'shen', 'guo', '##fan', '##g', 'told', 'reuters', ':', '"', 'the', 'necessary', 'atmosphere', 'for', 'the', 'opening', 'of', 'the', 'talks', 'has', 'been', 'disrupted', 'by', 'the', 'taiwan', 'authorities', '.', '"']
# Detokenized (047): ['speaking', 'only', 'hours', 'after', 'chinese', 'state', 'media', 'said', 'the', 'time', 'was', 'right', 'to', 'engage', 'in', 'political', 'talks', 'with', 'taiwan', ',', 'foreign', 'ministry', 'spokesman', 'shen', 'guo##fan##g', 'told', 'reuters', ':', '"', 'the', 'necessary', 'atmosphere', 'for', 'the', 'opening', 'of', 'the', 'talks', 'has', 'been', 'disrupted', 'by', 'the', 'taiwan', 'authorities', '.', '"']
# Counter: 49
# ===================================================================
# Hidden states:  (7, 47, 768)
# # Extracted words:  47
# Sentence         : "State media quoted China 's top negotiator with Taipei , Tang Shubei , as telling a visiting group from Taiwan on Wednesday that it was time for the rivals to hold political talks ."
# Original    (034): ['State', 'media', 'quoted', 'China', "'s", 'top', 'negotiator', 'with', 'Taipei', ',', 'Tang', 'Shubei', ',', 'as', 'telling', 'a', 'visiting', 'group', 'from', 'Taiwan', 'on', 'Wednesday', 'that', 'it', 'was', 'time', 'for', 'the', 'rivals', 'to', 'hold', 'political', 'talks', '.']
# Tokenized   (041): ['[CLS]', 'state', 'media', 'quoted', 'china', "'", 's', 'top', 'ne', '##go', '##tia', '##tor', 'with', 'taipei', ',', 'tang', 'shu', '##bei', ',', 'as', 'telling', 'a', 'visiting', 'group', 'from', 'taiwan', 'on', 'wednesday', 'that', 'it', 'was', 'time', 'for', 'the', 'rivals', 'to', 'hold', 'political', 'talks', '.', '[SEP]']
# Filtered   (039): ['state', 'media', 'quoted', 'china', "'", 's', 'top', 'ne', '##go', '##tia', '##tor', 'with', 'taipei', ',', 'tang', 'shu', '##bei', ',', 'as', 'telling', 'a', 'visiting', 'group', 'from', 'taiwan', 'on', 'wednesday', 'that', 'it', 'was', 'time', 'for', 'the', 'rivals', 'to', 'hold', 'political', 'talks', '.']
# Detokenized (034): ['state', 'media', 'quoted', 'china', "'s", 'top', 'ne##go##tia##tor', 'with', 'taipei', ',', 'tang', 'shu##bei', ',', 'as', 'telling', 'a', 'visiting', 'group', 'from', 'taiwan', 'on', 'wednesday', 'that', 'it', 'was', 'time', 'for', 'the', 'rivals', 'to', 'hold', 'political', 'talks', '.']
# Counter: 39
# ===================================================================
# Hidden states:  (7, 34, 768)
# # Extracted words:  34
# Sentence         : "" Now is the time for the two sides to engage in political talks ..."
# Original    (015): ['"', 'Now', 'is', 'the', 'time', 'for', 'the', 'two', 'sides', 'to', 'engage', 'in', 'political', 'talks', '...']
# Tokenized   (019): ['[CLS]', '"', 'now', 'is', 'the', 'time', 'for', 'the', 'two', 'sides', 'to', 'engage', 'in', 'political', 'talks', '.', '.', '.', '[SEP]']
# Filtered   (017): ['"', 'now', 'is', 'the', 'time', 'for', 'the', 'two', 'sides', 'to', 'engage', 'in', 'political', 'talks', '.', '.', '.']
# Detokenized (015): ['"', 'now', 'is', 'the', 'time', 'for', 'the', 'two', 'sides', 'to', 'engage', 'in', 'political', 'talks', '...']
# Counter: 17
# ===================================================================
# Hidden states:  (7, 15, 768)
# # Extracted words:  15
# Sentence         : "that is to end the state of hostility , " Thursday 's overseas edition of the People 's Daily quoted Tang as saying ."
# Original    (024): ['that', 'is', 'to', 'end', 'the', 'state', 'of', 'hostility', ',', '"', 'Thursday', "'s", 'overseas', 'edition', 'of', 'the', 'People', "'s", 'Daily', 'quoted', 'Tang', 'as', 'saying', '.']
# Tokenized   (028): ['[CLS]', 'that', 'is', 'to', 'end', 'the', 'state', 'of', 'hostility', ',', '"', 'thursday', "'", 's', 'overseas', 'edition', 'of', 'the', 'people', "'", 's', 'daily', 'quoted', 'tang', 'as', 'saying', '.', '[SEP]']
# Filtered   (026): ['that', 'is', 'to', 'end', 'the', 'state', 'of', 'hostility', ',', '"', 'thursday', "'", 's', 'overseas', 'edition', 'of', 'the', 'people', "'", 's', 'daily', 'quoted', 'tang', 'as', 'saying', '.']
# Detokenized (024): ['that', 'is', 'to', 'end', 'the', 'state', 'of', 'hostility', ',', '"', 'thursday', "'s", 'overseas', 'edition', 'of', 'the', 'people', "'s", 'daily', 'quoted', 'tang', 'as', 'saying', '.']
# Counter: 26
# ===================================================================
# Hidden states:  (7, 24, 768)
# # Extracted words:  24
# Sentence         : "The foreign ministry 's Shen told Reuters Television in an interview he had read reports of Tang 's comments but gave no details of why the negotiator had considered the time right for talks with Taiwan , which Beijing considers a renegade province ."
# Original    (044): ['The', 'foreign', 'ministry', "'s", 'Shen', 'told', 'Reuters', 'Television', 'in', 'an', 'interview', 'he', 'had', 'read', 'reports', 'of', 'Tang', "'s", 'comments', 'but', 'gave', 'no', 'details', 'of', 'why', 'the', 'negotiator', 'had', 'considered', 'the', 'time', 'right', 'for', 'talks', 'with', 'Taiwan', ',', 'which', 'Beijing', 'considers', 'a', 'renegade', 'province', '.']
# Tokenized   (051): ['[CLS]', 'the', 'foreign', 'ministry', "'", 's', 'shen', 'told', 'reuters', 'television', 'in', 'an', 'interview', 'he', 'had', 'read', 'reports', 'of', 'tang', "'", 's', 'comments', 'but', 'gave', 'no', 'details', 'of', 'why', 'the', 'ne', '##go', '##tia', '##tor', 'had', 'considered', 'the', 'time', 'right', 'for', 'talks', 'with', 'taiwan', ',', 'which', 'beijing', 'considers', 'a', 'renegade', 'province', '.', '[SEP]']
# Filtered   (049): ['the', 'foreign', 'ministry', "'", 's', 'shen', 'told', 'reuters', 'television', 'in', 'an', 'interview', 'he', 'had', 'read', 'reports', 'of', 'tang', "'", 's', 'comments', 'but', 'gave', 'no', 'details', 'of', 'why', 'the', 'ne', '##go', '##tia', '##tor', 'had', 'considered', 'the', 'time', 'right', 'for', 'talks', 'with', 'taiwan', ',', 'which', 'beijing', 'considers', 'a', 'renegade', 'province', '.']
# Detokenized (044): ['the', 'foreign', 'ministry', "'s", 'shen', 'told', 'reuters', 'television', 'in', 'an', 'interview', 'he', 'had', 'read', 'reports', 'of', 'tang', "'s", 'comments', 'but', 'gave', 'no', 'details', 'of', 'why', 'the', 'ne##go##tia##tor', 'had', 'considered', 'the', 'time', 'right', 'for', 'talks', 'with', 'taiwan', ',', 'which', 'beijing', 'considers', 'a', 'renegade', 'province', '.']
# Counter: 49
# ===================================================================
# Hidden states:  (7, 44, 768)
# # Extracted words:  44
# Sentence         : "China , which has long opposed all Taipei efforts to gain greater international recognition , was infuriated by a visit to Ukraine this week by Taiwanese Vice President Lien ."
# Original    (030): ['China', ',', 'which', 'has', 'long', 'opposed', 'all', 'Taipei', 'efforts', 'to', 'gain', 'greater', 'international', 'recognition', ',', 'was', 'infuriated', 'by', 'a', 'visit', 'to', 'Ukraine', 'this', 'week', 'by', 'Taiwanese', 'Vice', 'President', 'Lien', '.']
# Tokenized   (035): ['[CLS]', 'china', ',', 'which', 'has', 'long', 'opposed', 'all', 'taipei', 'efforts', 'to', 'gain', 'greater', 'international', 'recognition', ',', 'was', 'in', '##fur', '##iated', 'by', 'a', 'visit', 'to', 'ukraine', 'this', 'week', 'by', 'taiwanese', 'vice', 'president', 'lie', '##n', '.', '[SEP]']
# Filtered   (033): ['china', ',', 'which', 'has', 'long', 'opposed', 'all', 'taipei', 'efforts', 'to', 'gain', 'greater', 'international', 'recognition', ',', 'was', 'in', '##fur', '##iated', 'by', 'a', 'visit', 'to', 'ukraine', 'this', 'week', 'by', 'taiwanese', 'vice', 'president', 'lie', '##n', '.']
# Detokenized (030): ['china', ',', 'which', 'has', 'long', 'opposed', 'all', 'taipei', 'efforts', 'to', 'gain', 'greater', 'international', 'recognition', ',', 'was', 'in##fur##iated', 'by', 'a', 'visit', 'to', 'ukraine', 'this', 'week', 'by', 'taiwanese', 'vice', 'president', 'lie##n', '.']
# Counter: 33
# ===================================================================
# Hidden states:  (7, 30, 768)
# # Extracted words:  30
# Sentence         : "China says time right for Taiwan talks ."
# ...
# Detokenized (003): ['26.', 'ukraine', '8.09']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "26. Spain 8.09"
# Original    (003): ['26.', 'Spain', '8.09']
# Tokenized   (008): ['[CLS]', '26', '.', 'spain', '8', '.', '09', '[SEP]']
# Filtered   (006): ['26', '.', 'spain', '8', '.', '09']
# Detokenized (003): ['26.', 'spain', '8.09']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "26. Finland 8.09"
# Original    (003): ['26.', 'Finland', '8.09']
# Tokenized   (008): ['[CLS]', '26', '.', 'finland', '8', '.', '09', '[SEP]']
# Filtered   (006): ['26', '.', 'finland', '8', '.', '09']
# Detokenized (003): ['26.', 'finland', '8.09']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "29. Macedonia 8.07"
# Original    (003): ['29.', 'Macedonia', '8.07']
# Tokenized   (008): ['[CLS]', '29', '.', 'macedonia', '8', '.', '07', '[SEP]']
# Filtered   (006): ['29', '.', 'macedonia', '8', '.', '07']
# Detokenized (003): ['29.', 'macedonia', '8.07']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "30. Lithuania 8.06"
# Original    (003): ['30.', 'Lithuania', '8.06']
# Tokenized   (008): ['[CLS]', '30', '.', 'lithuania', '8', '.', '06', '[SEP]']
# Filtered   (006): ['30', '.', 'lithuania', '8', '.', '06']
# Detokenized (003): ['30.', 'lithuania', '8.06']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "31. Austria 8.05"
# Original    (003): ['31.', 'Austria', '8.05']
# Tokenized   (008): ['[CLS]', '31', '.', 'austria', '8', '.', '05', '[SEP]']
# Filtered   (006): ['31', '.', 'austria', '8', '.', '05']
# Detokenized (003): ['31.', 'austria', '8.05']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "32. Russia 8.03"
# Original    (003): ['32.', 'Russia', '8.03']
# Tokenized   (008): ['[CLS]', '32', '.', 'russia', '8', '.', '03', '[SEP]']
# Filtered   (006): ['32', '.', 'russia', '8', '.', '03']
# Detokenized (003): ['32.', 'russia', '8.03']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "33. Romania 8.02"
# Original    (003): ['33.', 'Romania', '8.02']
# Tokenized   (008): ['[CLS]', '33', '.', 'romania', '8', '.', '02', '[SEP]']
# Filtered   (006): ['33', '.', 'romania', '8', '.', '02']
# Detokenized (003): ['33.', 'romania', '8.02']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "33. Turkey 8.02"
# Original    (003): ['33.', 'Turkey', '8.02']
# Tokenized   (008): ['[CLS]', '33', '.', 'turkey', '8', '.', '02', '[SEP]']
# Filtered   (006): ['33', '.', 'turkey', '8', '.', '02']
# Detokenized (003): ['33.', 'turkey', '8.02']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "35. Hungary 7.98"
# Original    (003): ['35.', 'Hungary', '7.98']
# Tokenized   (008): ['[CLS]', '35', '.', 'hungary', '7', '.', '98', '[SEP]']
# Filtered   (006): ['35', '.', 'hungary', '7', '.', '98']
# Detokenized (003): ['35.', 'hungary', '7.98']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "36. Czech Republic 7.95"
# Original    (004): ['36.', 'Czech', 'Republic', '7.95']
# Tokenized   (009): ['[CLS]', '36', '.', 'czech', 'republic', '7', '.', '95', '[SEP]']
# Filtered   (007): ['36', '.', 'czech', 'republic', '7', '.', '95']
# Detokenized (004): ['36.', 'czech', 'republic', '7.95']
# Counter: 7
# ===================================================================
# Hidden states:  (7, 4, 768)
# # Extracted words:  4
# Sentence         : "37. Greece 7.89"
# Original    (003): ['37.', 'Greece', '7.89']
# Tokenized   (008): ['[CLS]', '37', '.', 'greece', '7', '.', '89', '[SEP]']
# Filtered   (006): ['37', '.', 'greece', '7', '.', '89']
# Detokenized (003): ['37.', 'greece', '7.89']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "37. Northern Ireland 7.89"
# Original    (004): ['37.', 'Northern', 'Ireland', '7.89']
# Tokenized   (009): ['[CLS]', '37', '.', 'northern', 'ireland', '7', '.', '89', '[SEP]']
# Filtered   (007): ['37', '.', 'northern', 'ireland', '7', '.', '89']
# Detokenized (004): ['37.', 'northern', 'ireland', '7.89']
# Counter: 7
# ===================================================================
# Hidden states:  (7, 4, 768)
# # Extracted words:  4
# Sentence         : "39. Italy 7.85"
# Original    (003): ['39.', 'Italy', '7.85']
# Tokenized   (008): ['[CLS]', '39', '.', 'italy', '7', '.', '85', '[SEP]']
# Filtered   (006): ['39', '.', 'italy', '7', '.', '85']
# Detokenized (003): ['39.', 'italy', '7.85']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "40. Cyprus 7.83"
# Original    (003): ['40.', 'Cyprus', '7.83']
# Tokenized   (008): ['[CLS]', '40', '.', 'cyprus', '7', '.', '83', '[SEP]']
# Filtered   (006): ['40', '.', 'cyprus', '7', '.', '83']
# Detokenized (003): ['40.', 'cyprus', '7.83']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "41. Armenia 7.80"
# Original    (003): ['41.', 'Armenia', '7.80']
# Tokenized   (008): ['[CLS]', '41', '.', 'armenia', '7', '.', '80', '[SEP]']
# Filtered   (006): ['41', '.', 'armenia', '7', '.', '80']
# Detokenized (003): ['41.', 'armenia', '7.80']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "42. Slovenia 7.77"
# Original    (003): ['42.', 'Slovenia', '7.77']
# Tokenized   (008): ['[CLS]', '42', '.', 'slovenia', '7', '.', '77', '[SEP]']
# Filtered   (006): ['42', '.', 'slovenia', '7', '.', '77']
# Detokenized (003): ['42.', 'slovenia', '7.77']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "43. Croatia 7.75"
# Original    (003): ['43.', 'Croatia', '7.75']
# Tokenized   (008): ['[CLS]', '43', '.', 'croatia', '7', '.', '75', '[SEP]']
# Filtered   (006): ['43', '.', 'croatia', '7', '.', '75']
# Detokenized (003): ['43.', 'croatia', '7.75']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "44. Bulgaria 7.73"
# Original    (003): ['44.', 'Bulgaria', '7.73']
# Tokenized   (008): ['[CLS]', '44', '.', 'bulgaria', '7', '.', '73', '[SEP]']
# Filtered   (006): ['44', '.', 'bulgaria', '7', '.', '73']
# Detokenized (003): ['44.', 'bulgaria', '7.73']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "45. Malta 7.40"
# Original    (003): ['45.', 'Malta', '7.40']
# Tokenized   (008): ['[CLS]', '45', '.', 'malta', '7', '.', '40', '[SEP]']
# Filtered   (006): ['45', '.', 'malta', '7', '.', '40']
# Detokenized (003): ['45.', 'malta', '7.40']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 3, 768)
# # Extracted words:  3
# Sentence         : "CRICKET - POLICE COMMANDOS ON HAND FOR AUSTRALIANS ' FIRST MATCH ."
# Original    (012): ['CRICKET', '-', 'POLICE', 'COMMANDOS', 'ON', 'HAND', 'FOR', 'AUSTRALIANS', "'", 'FIRST', 'MATCH', '.']
# Tokenized   (014): ['[CLS]', 'cricket', '-', 'police', 'commandos', 'on', 'hand', 'for', 'australians', "'", 'first', 'match', '.', '[SEP]']
# Filtered   (012): ['cricket', '-', 'police', 'commandos', 'on', 'hand', 'for', 'australians', "'", 'first', 'match', '.']
# Detokenized (012): ['cricket', '-', 'police', 'commandos', 'on', 'hand', 'for', 'australians', "'", 'first', 'match', '.']
# Counter: 12
# ===================================================================
# Hidden states:  (7, 12, 768)
# # Extracted words:  12
# Sentence         : "COLOMBO 1996-08-22"
# Original    (002): ['COLOMBO', '1996-08-22']
# Tokenized   (008): ['[CLS]', 'colombo', '1996', '-', '08', '-', '22', '[SEP]']
# Filtered   (006): ['colombo', '1996', '-', '08', '-', '22']
# Detokenized (002): ['colombo', '1996-08-22']
# Counter: 6
# ===================================================================
# Hidden states:  (7, 2, 768)
# # Extracted words:  2
# Sentence         : "Armed police commandos patrolled the ground when Australia opened their short tour of Sri Lanka with a five-run win over the country 's youth team on Thursday ."
# Original    (028): ['Armed', 'police', 'commandos', 'patrolled', 'the', 'ground', 'when', 'Australia', 'opened', 'their', 'short', 'tour', 'of', 'Sri', 'Lanka', 'with', 'a', 'five-run', 'win', 'over', 'the', 'country', "'s", 'youth', 'team', 'on', 'Thursday', '.']
# Tokenized   (034): ['[CLS]', 'armed', 'police', 'commandos', 'patrol', '##led', 'the', 'ground', 'when', 'australia', 'opened', 'their', 'short', 'tour', 'of', 'sri', 'lanka', 'with', 'a', 'five', '-', 'run', 'win', 'over', 'the', 'country', "'", 's', 'youth', 'team', 'on', 'thursday', '.', '[SEP]']
# Filtered   (032): ['armed', 'police', 'commandos', 'patrol', '##led', 'the', 'ground', 'when', 'australia', 'opened', 'their', 'short', 'tour', 'of', 'sri', 'lanka', 'with', 'a', 'five', '-', 'run', 'win', 'over', 'the', 'country', "'", 's', 'youth', 'team', 'on', 'thursday', '.']
# Detokenized (028): ['armed', 'police', 'commandos', 'patrol##led', 'the', 'ground', 'when', 'australia', 'opened', 'their', 'short', 'tour', 'of', 'sri', 'lanka', 'with', 'a', 'five-run', 'win', 'over', 'the', 'country', "'s", 'youth', 'team', 'on', 'thursday', '.']
# Counter: 32
# ===================================================================
# Hidden states:  (7, 28, 768)
# # Extracted words:  28
# Sentence         : "Australia , in Sri Lanka for a limited overs tournament which also includes India and Zimbabwe , have been promised the presence of commandos , sniffer dogs and plainclothes policemen to ensure the tournament is trouble-free ."
# Original    (037): ['Australia', ',', 'in', 'Sri', 'Lanka', 'for', 'a', 'limited', 'overs', 'tournament', 'which', 'also', 'includes', 'India', 'and', 'Zimbabwe', ',', 'have', 'been', 'promised', 'the', 'presence', 'of', 'commandos', ',', 'sniffer', 'dogs', 'and', 'plainclothes', 'policemen', 'to', 'ensure', 'the', 'tournament', 'is', 'trouble-free', '.']
# Tokenized   (044): ['[CLS]', 'australia', ',', 'in', 'sri', 'lanka', 'for', 'a', 'limited', 'overs', 'tournament', 'which', 'also', 'includes', 'india', 'and', 'zimbabwe', ',', 'have', 'been', 'promised', 'the', 'presence', 'of', 'commandos', ',', 'sniff', '##er', 'dogs', 'and', 'plain', '##cloth', '##es', 'policemen', 'to', 'ensure', 'the', 'tournament', 'is', 'trouble', '-', 'free', '.', '[SEP]']
# Filtered   (042): ['australia', ',', 'in', 'sri', 'lanka', 'for', 'a', 'limited', 'overs', 'tournament', 'which', 'also', 'includes', 'india', 'and', 'zimbabwe', ',', 'have', 'been', 'promised', 'the', 'presence', 'of', 'commandos', ',', 'sniff', '##er', 'dogs', 'and', 'plain', '##cloth', '##es', 'policemen', 'to', 'ensure', 'the', 'tournament', 'is', 'trouble', '-', 'free', '.']
# Detokenized (037): ['australia', ',', 'in', 'sri', 'lanka', 'for', 'a', 'limited', 'overs', 'tournament', 'which', 'also', 'includes', 'india', 'and', 'zimbabwe', ',', 'have', 'been', 'promised', 'the', 'presence', 'of', 'commandos', ',', 'sniff##er', 'dogs', 'and', 'plain##cloth##es', 'policemen', 'to', 'ensure', 'the', 'tournament', 'is', 'trouble-free', '.']
# Counter: 42
# ===================================================================
# Hidden states:  (7, 37, 768)
# # Extracted words:  37
# Sentence         : "They are making their first visit to the island since boycotting a World Cup fixture in February because of fears over ethnic violence ."
# Original    (024): ['They', 'are', 'making', 'their', 'first', 'visit', 'to', 'the', 'island', 'since', 'boycotting', 'a', 'World', 'Cup', 'fixture', 'in', 'February', 'because', 'of', 'fears', 'over', 'ethnic', 'violence', '.']
# Tokenized   (027): ['[CLS]', 'they', 'are', 'making', 'their', 'first', 'visit', 'to', 'the', 'island', 'since', 'boycott', '##ing', 'a', 'world', 'cup', 'fixture', 'in', 'february', 'because', 'of', 'fears', 'over', 'ethnic', 'violence', '.', '[SEP]']
# Filtered   (025): ['they', 'are', 'making', 'their', 'first', 'visit', 'to', 'the', 'island', 'since', 'boycott', '##ing', 'a', 'world', 'cup', 'fixture', 'in', 'february', 'because', 'of', 'fears', 'over', 'ethnic', 'violence', '.']
# Detokenized (024): ['they', 'are', 'making', 'their', 'first', 'visit', 'to', 'the', 'island', 'since', 'boycott##ing', 'a', 'world', 'cup', 'fixture', 'in', 'february', 'because', 'of', 'fears', 'over', 'ethnic', 'violence', '.']
# Counter: 25
# ===================================================================
# Hidden states:  (7, 24, 768)
# # Extracted words:  24
# Sentence         : "Australia , batting first in Thursday 's the warm-up match , scored 251 for seven from their 50 overs ."
# Original    (020): ['Australia', ',', 'batting', 'first', 'in', 'Thursday', "'s", 'the', 'warm-up', 'match', ',', 'scored', '251', 'for', 'seven', 'from', 'their', '50', 'overs', '.']
# Tokenized   (025): ['[CLS]', 'australia', ',', 'batting', 'first', 'in', 'thursday', "'", 's', 'the', 'warm', '-', 'up', 'match', ',', 'scored', '251', 'for', 'seven', 'from', 'their', '50', 'overs', '.', '[SEP]']
# Filtered   (023): ['australia', ',', 'batting', 'first', 'in', 'thursday', "'", 's', 'the', 'warm', '-', 'up', 'match', ',', 'scored', '251', 'for', 'seven', 'from', 'their', '50', 'overs', '.']
# Detokenized (020): ['australia', ',', 'batting', 'first', 'in', 'thursday', "'s", 'the', 'warm-up', 'match', ',', 'scored', '251', 'for', 'seven', 'from', 'their', '50', 'overs', '.']
# Counter: 23
# ===================================================================
# Hidden states:  (7, 20, 768)
# # Extracted words:  20
# Sentence         : "Ricky Ponting led the way with 100 off 119 balls with two sixes and nine fours before retiring ."
# Original    (019): ['Ricky', 'Ponting', 'led', 'the', 'way', 'with', '100', 'off', '119', 'balls', 'with', 'two', 'sixes', 'and', 'nine', 'fours', 'before', 'retiring', '.']
# Tokenized   (023): ['[CLS]', 'ricky', 'pont', '##ing', 'led', 'the', 'way', 'with', '100', 'off', '119', 'balls', 'with', 'two', 'six', '##es', 'and', 'nine', 'fours', 'before', 'retiring', '.', '[SEP]']
# Filtered   (021): ['ricky', 'pont', '##ing', 'led', 'the', 'way', 'with', '100', 'off', '119', 'balls', 'with', 'two', 'six', '##es', 'and', 'nine', 'fours', 'before', 'retiring', '.']
# Detokenized (019): ['ricky', 'pont##ing', 'led', 'the', 'way', 'with', '100', 'off', '119', 'balls', 'with', 'two', 'six##es', 'and', 'nine', 'fours', 'before', 'retiring', '.']
# Counter: 21
# ===================================================================
# Hidden states:  (7, 19, 768)
# # Extracted words:  19
# Sentence         : "The youth side replied with 246 for seven ."
# Original    (009): ['The', 'youth', 'side', 'replied', 'with', '246', 'for', 'seven', '.']
# Tokenized   (011): ['[CLS]', 'the', 'youth', 'side', 'replied', 'with', '246', 'for', 'seven', '.', '[SEP]']
# Filtered   (009): ['the', 'youth', 'side', 'replied', 'with', '246', 'for', 'seven', '.']
# Detokenized (009): ['the', 'youth', 'side', 'replied', 'with', '246', 'for', 'seven', '.']
# Counter: 9
# ===================================================================
# Hidden states:  (7, 9, 768)
# # Extracted words:  9

# %%
# !cut -c1-120 < activations.json
# Out:
# {"linex_index": 0, "features": [{"token": "this", "layers": [{"index": 0, "values": [-0.6485135, 0.67392403, -0.09324985
# {"linex_index": 1, "features": [{"token": "this", "layers": [{"index": 0, "values": [-0.6485135, 0.67392403, -0.09324985
# {"linex_index": 2, "features": [{"token": "the", "layers": [{"index": 0, "values": [-0.43669653, 0.53601718, -0.05141334
# {"linex_index": 3, "features": [{"token": "this", "layers": [{"index": 0, "values": [-0.6485135, 0.67392403, -0.09324985
# {"linex_index": 4, "features": [{"token": "individual", "layers": [{"index": 0, "values": [0.14265811, 0.75676745, -0.91
# {"linex_index": 5, "features": [{"token": "it", "layers": [{"index": 0, "values": [-0.42272022, -0.02889436, -0.14556105
# {"linex_index": 6, "features": [{"token": "the", "layers": [{"index": 0, "values": [-0.43669653, 0.53601718, -0.05141334
# {"linex_index": 7, "features": [{"token": "is", "layers": [{"index": 0, "values": [-0.29041198, 0.00098542, -0.43960977,
# {"linex_index": 8, "features": [{"token": "there", "layers": [{"index": 0, "values": [-0.92661953, 0.54027897, -0.121723
# {"linex_index": 9, "features": [{"token": "hope", "layers": [{"index": 0, "values": [-0.52321094, 0.09137478, -0.5700546

# %% [markdown]
# # Prepare Data

# %%
import neurox.data.loader as data_loader
activations, num_layers = data_loader.load_activations('activations.json', 768)
# Out:
# Loading json activations from activations.json...
# 10 13.0

# %%
print(activations)
# Out:
# [array([[-0.6485135 ,  0.67392403, -0.09324985, ..., -0.5617491 ,
#          0.48687834,  0.54459047],
#        [-0.62703037, -0.06331295, -0.31427881, ..., -0.15095142,
#          0.20867236,  0.97557974],
#        [ 0.39637804,  0.31565616,  0.02008923, ..., -0.07199516,
#          0.2717956 ,  1.4120574 ],
#        [ 0.60103226, -0.69701707, -0.2000732 , ..., -0.72475618,
#          0.08129568, -0.25088236],
#        [ 0.83230692,  0.28782725,  0.00214796, ..., -0.11331076,
#         -0.15800183, -0.34240773],
#        [-0.078184  ,  0.01739771, -0.28644535, ...,  0.20194323,
#         -0.62845349, -0.45307434]]), array([[-0.6485135 ,  0.67392403, -0.09324985, ..., -0.1489853 ,
#          0.25174388,  0.49430278],
#        [-0.62703037, -0.06331295, -0.31427881, ..., -0.08159983,
#          0.22553164,  1.23856652],
#        [ 0.17470703,  0.5296641 ,  0.15547034, ..., -0.02144399,
#          0.16490568,  0.45266795],
#        [ 0.79593539,  0.43478003,  0.19534861, ...,  0.24064474,
#         -0.1610865 , -0.04338051],
#        [-0.24421799, -0.00505799, -0.2361756 , ...,  0.18171117,
#         -0.59807694, -0.40410802]]), array([[-0.43669653,  0.53601718, -0.05141334, ...,  0.08916449,
#         -0.03631125, -0.25833285],
#        [-0.40620843, -0.02407933,  0.07018298, ..., -0.45780778,
#         -0.09455121,  0.04842313],
#        [-0.63621354, -0.58316255, -0.02177599, ..., -0.22923732,
#         -0.20186169, -0.22577222],
#        ...,
#        [-0.51149249,  0.08505765, -0.07088199, ..., -0.49211657,
#         -0.12688015,  0.24504447],
#        [-0.38502297,  0.67937475, -0.53690284, ..., -0.73168516,
#         -0.43015927, -0.1082015 ],
#        [ 0.63080698, -0.06970568, -0.55951494, ...,  0.54653454,
#         -0.01394553,  0.04647673]]), array([[-0.6485135 ,  0.67392403, -0.09324985, ..., -0.53436476,
#          0.50848675,  0.13532165],
#        [ 0.69533932,  0.57200843,  0.12022351, ..., -0.4209151 ,
#         -0.31094483, -0.20510523],
#        [ 0.25860026, -0.13158366,  0.24129908, ..., -0.47548753,
#         -0.56652617,  0.49130359],
#        ...,
#        [ 1.01413512,  0.06053618, -0.49695262, ..., -0.12298191,
#         -0.03628948,  0.46071082],
#        [ 0.63052869,  0.85758877,  0.13605389, ..., -0.25956559,
#          0.05945413,  0.36230397],
#        [-0.38998938,  0.37895441, -0.20082907, ...,  0.19299863,
#         -0.74163234, -0.34806266]]), array([[ 0.14265811,  0.75676745, -0.91309988, ..., -0.09842324,
#          0.24984533, -0.01557633],
#        [-0.42477405, -0.08116548, -0.15442267, ..., -0.63717115,
#         -0.02130724,  0.10692144],
#        [-0.1452172 , -0.03716256, -0.54431528, ..., -0.76554811,
#         -0.51652509, -0.48392284],
#        ...,
#        [ 0.59812301,  0.03694542, -0.52747393, ..., -0.41165909,
#         -0.76464164, -0.21928369],
#        [-0.71476042,  0.76875144,  0.60540003, ...,  0.1254333 ,
#         -0.61107832, -0.64693165],
#        [-0.35849679,  0.27769977, -0.12096424, ...,  0.2860468 ,
#         -0.63741863, -0.39587516]]), array([[-0.42272022, -0.02889436, -0.14556105, ...,  0.18005052,
#          0.96683419,  0.92049372],
#        [-0.62703037, -0.06331295, -0.31427881, ..., -0.4218764 ,
#         -0.02237501,  0.68321967],
#        [ 0.39637804,  0.31565616,  0.02008923, ...,  0.04472378,
#          0.06281326,  1.15459895],
#        ...,
#        [-0.32710102,  0.09780598, -0.00499107, ...,  0.24449876,
#         -0.13542813,  0.05680061],
#        [-0.12954706, -0.19889867, -0.87076139, ..., -0.04338097,
#         -0.06888913,  0.10935353],
#        [-0.17839175,  0.04546055, -0.05272707, ...,  0.09168065,
#         -0.18895845, -0.635207  ]]), array([[-0.43669653,  0.53601718, -0.05141334, ...,  0.05464496,
#          0.84184313, -0.03606783],
#        [-0.83640105, -0.32306263, -0.53736091, ..., -0.36387503,
#          0.34840685, -0.07092541],
#        [ 0.49358484,  0.41512093, -0.31682363, ..., -0.66553563,
#         -0.49735495, -0.07163969],
#        ...,
#        [ 0.23573056, -0.02283433,  0.43932545, ..., -0.18176727,
#         -0.50771236,  1.20476031],
#        [-0.62729764, -1.20988607,  0.08798195, ..., -0.06347735,
#         -0.06996888, -0.01871283],
#        [ 0.78433746, -0.50467217, -0.54002684, ...,  0.56473744,
#          0.10865708,  0.13554665]]), array([[-2.9041198e-01,  9.8542000e-04, -4.3960977e-01, ...,
#          1.1124226e-01,  9.8703301e-01,  6.2520158e-01],
#        [-9.8460042e-01,  6.1801237e-01,  4.0445110e-02, ...,
#         -1.4134920e-02, -2.4952230e-02,  5.9878659e-01],
#        [ 3.9637804e-01,  3.1565616e-01,  2.0089230e-02, ...,
#         -3.7455390e-02, -6.3511200e-03,  9.7207773e-01],
#        [ 5.4330373e-01, -6.5850198e-01,  6.4455175e-01, ...,
#         -6.4713949e-01, -2.8366232e-01, -2.4487631e-01],
#        [ 4.3205398e-01, -4.3607795e-01, -4.9595901e-01, ...,
#         -4.0459770e-02,  2.0927911e-01,  3.5239965e-01]]), array([[-0.92661953,  0.54027897, -0.12172387, ..., -0.58335567,
#          0.4648461 ,  0.38044229],
#        [-0.23301628,  0.11637446,  0.50870693, ..., -0.59583622,
#          0.01661224,  0.72063446],
#        [ 0.7006678 ,  0.35107133, -0.41721863, ..., -0.11240292,
#          0.14902288,  0.77660489],
#        ...,
#        [-0.28386125,  0.50497276, -0.57497823, ..., -0.23774076,
#          0.23928863,  0.62906986],
#        [ 0.06143352,  0.95696741, -0.4678036 , ..., -0.69031185,
#          0.10743558,  0.61447704],
#        [-0.38998938,  0.37895441, -0.20082907, ...,  0.17793518,
#         -0.43352988, -0.39432263]]), array([[-0.52321094,  0.09137478, -0.57005465, ..., -0.11681473,
#          0.22681607, -0.25711259],
#        [-0.6288358 ,  0.44862282,  0.63139808, ...,  0.38343543,
#          0.2238639 , -1.13947427],
#        [-0.10686638, -0.04964682,  0.34876883, ..., -0.17335287,
#          0.20482135, -0.01073296],
#        ...,
#        [-0.62476927,  0.18336678, -0.03624243, ...,  0.40376812,
#          0.26292151, -0.36223418],
#        [-0.23480649, -0.51989293, -0.01166019, ..., -0.15865815,
#          0.2571224 , -0.26102802],
#        [ 0.78433746, -0.50467217, -0.54002684, ...,  0.47051007,
#          0.30643499, -0.47045979]])]

# %%
activations[0].shape # 9984 -> 768 * 13
# Out:
# (6, 9984)

# %%
activations[1].shape
# Out:
# (5, 9984)

# %%
# load_data also does sanity checks for parallelism between tokens, labels and activations
tokens = data_loader.load_data('test.in',
                               'test.label',
                               activations,
                               512 # max_sent_l
                              )

# %%
tokens
# Out:
# {'source': [['This', 'is', 'a', 'test', 'sentence', '.'],
#   ['This', 'is', 'another', 'sentence', '.'],
#   ['The',
#    'NeuroX',
#    'toolkit',
#    'can',
#    'be',
#    'used',
#    'for',
#    'neuron',
#    'analysis',
#    '!'],
#   ['This', 'sentence', 'contains', 'an', '<<UNKNOWN>>', 'word', '.'],
#   ['Individual', 'neuron', 'activations', 'can', 'be', 'insightful', '.'],
#   ['It', 'is', 'a', 'beautiful', 'day', 'outside', '.'],
#   ['The', 'red', 'car', 'zoomed', 'by', 'quickly', '!'],
#   ['Is', 'this', 'a', 'question', '?'],
#   ['There',
#    'are',
#    'more',
#    'than',
#    '10000',
#    'neurons',
#    'in',
#    'some',
#    'models',
#    '.'],
#   ['Hope', 'you', 'are', 'enjoying', 'the', 'tutorial', '!']],
#  'target': [['DT', 'VBZ', 'DT', 'NN', 'NN', '.'],
#   ['DT', 'VBZ', 'DT', 'NN', '.'],
#   ['DT', 'NNP', 'NN', 'MD', 'VB', 'VBN', 'IN', 'JJ', 'NN', '.'],
#   ['DT', 'NN', 'VBZ', 'DT', 'NN', 'NN', '.'],
#   ['NNP', 'CC', 'NNS', 'MD', 'VB', 'JJ', '.'],
#   ['PRP', 'VBZ', 'DT', 'JJ', 'NN', 'IN', '.'],
#   ['DT', 'JJ', 'NN', 'VBN', 'IN', 'RB', '.'],
#   ['VBZ', 'DT', 'DT', 'NN', '.'],
#   ['EX', 'VBP', 'JJR', 'IN', 'CD', 'NNS', 'IN', 'DT', 'NNS', '.'],
#   ['NN', 'PRP', 'VBP', 'VBG', 'DT', 'NN', '.']]}

# %%
import neurox.interpretation.utils as utils
X, y, mapping = utils.create_tensors(tokens, activations, 'NN')
label2idx, idx2label, src2idx, idx2src = mapping
# Out:
# Number of tokens:  71
# length of source dictionary:  51
# length of target dictionary:  19
# 71
# Total instances: 71
# ['models', 'zoomed', 'There', '?', '10000', 'activations', 'The', 'It', 'neuron', 'insightful', 'a', 'is', 'toolkit', 'than', 'analysis', 'used', 'day', 'in', 'contains', 'Is']

# %%
# X_dev, y_dev, mapping = utils.create_tensors(dev_tokens, dev_activations, 'LABEL1', mapping=mapping)
X[0] #9984
# Out:
# array([-0.6485135 ,  0.673924  , -0.09324985, ..., -0.5617491 ,
#         0.48687834,  0.5445905 ], dtype=float32)

# %% [markdown]
# # Train Probing Classifier

# %%
import neurox.interpretation.linear_probe as linear_probe
probe = linear_probe.train_logistic_regression_probe(X, y, lambda_l1=0.001, lambda_l2=0.001)
# Out:
# Training classification probe
# Creating model...
# Number of training instances: 71
# Number of classes: 19
# epoch [1/10]: 0it [00:00, ?it/s]
# Epoch: [1/10], Loss: 0.1507
# epoch [2/10]: 0it [00:00, ?it/s]
# Epoch: [2/10], Loss: 0.0456
# epoch [3/10]: 0it [00:00, ?it/s]
# Epoch: [3/10], Loss: 0.0428
# epoch [4/10]: 0it [00:00, ?it/s]
# Epoch: [4/10], Loss: 0.0423
# epoch [5/10]: 0it [00:00, ?it/s]
# Epoch: [5/10], Loss: 0.0417
# epoch [6/10]: 0it [00:00, ?it/s]
# Epoch: [6/10], Loss: 0.0409
# epoch [7/10]: 0it [00:00, ?it/s]
# Epoch: [7/10], Loss: 0.0396
# epoch [8/10]: 0it [00:00, ?it/s]
# Epoch: [8/10], Loss: 0.0379
# epoch [9/10]: 0it [00:00, ?it/s]
# Epoch: [9/10], Loss: 0.0360
# epoch [10/10]: 0it [00:00, ?it/s]
# Epoch: [10/10], Loss: 0.0339

# %% [markdown]
# # Evaluate Model

# %%
linear_probe.evaluate_probe(probe, X, y, idx_to_class=idx2label)
# Out:
# Evaluating: 0it [00:00, ?it/s]
# Score (accuracy) of the probe: 1.00
# {'__OVERALL__': 1.0,
#  'VBZ': 1.0,
#  'NNP': 1.0,
#  'VBN': 1.0,
#  'CC': 1.0,
#  'NNS': 1.0,
#  'PRP': 1.0,
#  'RB': 1.0,
#  'VBP': 1.0,
#  'JJ': 1.0,
#  'MD': 1.0,
#  'EX': 1.0,
#  'VB': 1.0,
#  'CD': 1.0,
#  'VBG': 1.0,
#  'IN': 1.0,
#  '.': 1.0,
#  'DT': 1.0,
#  'NN': 1.0,
#  'JJR': 1.0}

# %% [markdown]
# # Layerwise probing

# %%
# [layer0_neuron0, layer0_neuron1, layer0_neuron2 ...., layer1_neuron0, layer1_neuron1,....., layer13_neuron768]
# [768,768,770...1536] <- for layer 1
import neurox.interpretation.ablation as ablation

# %%
layer_0_X = ablation.filter_activations_by_layers(X, [0], 13)
print(layer_0_X.shape)
probe_layer_0 = linear_probe.train_logistic_regression_probe(layer_0_X, y, lambda_l1=0.001, lambda_l2=0.001)
linear_probe.evaluate_probe(probe_layer_0, layer_0_X, y, idx_to_class=idx2label)
# Out:
# (71, 768)
# Training classification probe
# Creating model...
# Number of training instances: 71
# Number of classes: 19
# epoch [1/10]: 0it [00:00, ?it/s]
# Epoch: [1/10], Loss: 0.1351
# epoch [2/10]: 0it [00:00, ?it/s]
# Epoch: [2/10], Loss: 0.1113
# epoch [3/10]: 0it [00:00, ?it/s]
# Epoch: [3/10], Loss: 0.0913
# epoch [4/10]: 0it [00:00, ?it/s]
# Epoch: [4/10], Loss: 0.0743
# epoch [5/10]: 0it [00:00, ?it/s]
# Epoch: [5/10], Loss: 0.0607
# epoch [6/10]: 0it [00:00, ?it/s]
# Epoch: [6/10], Loss: 0.0502
# epoch [7/10]: 0it [00:00, ?it/s]
# Epoch: [7/10], Loss: 0.0423
# epoch [8/10]: 0it [00:00, ?it/s]
# Epoch: [8/10], Loss: 0.0364
# epoch [9/10]: 0it [00:00, ?it/s]
# Epoch: [9/10], Loss: 0.0320
# epoch [10/10]: 0it [00:00, ?it/s]
# Epoch: [10/10], Loss: 0.0286
# Evaluating: 0it [00:00, ?it/s]
# Score (accuracy) of the probe: 1.00
# {'__OVERALL__': 1.0,
#  'VBZ': 1.0,
#  'NNP': 1.0,
#  'VBN': 1.0,
#  'CC': 1.0,
#  'NNS': 1.0,
#  'PRP': 1.0,
#  'RB': 1.0,
#  'VBP': 1.0,
#  'JJ': 1.0,
#  'MD': 1.0,
#  'EX': 1.0,
#  'VB': 1.0,
#  'CD': 1.0,
#  'VBG': 1.0,
#  'IN': 1.0,
#  '.': 1.0,
#  'DT': 1.0,
#  'NN': 1.0,
#  'JJR': 1.0}

# %% [markdown]
# # Get Neuron Ranking

# %%
ordering, cutoffs = linear_probe.get_neuron_ordering(probe, label2idx)
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]

# %%
ordering[:10]
# Out:
# [1473, 3081, 778, 6159, 4881, 6482, 5333, 8730, 8219, 7843]

# %% [markdown]
# # Train on top N neurons

# %%
X_selected = ablation.filter_activations_keep_neurons(X, ordering[:100])

# %%
X_selected.shape
# Out:
# (71, 100)

# %%
probe_selected = linear_probe.train_logistic_regression_probe(X_selected, y, lambda_l1=0.001, lambda_l2=0.001)
# Out:
# Training classification probe
# Creating model...
# Number of training instances: 71
# Number of classes: 19
# epoch [1/10]: 0it [00:00, ?it/s]
# Epoch: [1/10], Loss: 0.1340
# epoch [2/10]: 0it [00:00, ?it/s]
# Epoch: [2/10], Loss: 0.1292
# epoch [3/10]: 0it [00:00, ?it/s]
# Epoch: [3/10], Loss: 0.1248
# epoch [4/10]: 0it [00:00, ?it/s]
# Epoch: [4/10], Loss: 0.1205
# epoch [5/10]: 0it [00:00, ?it/s]
# Epoch: [5/10], Loss: 0.1164
# epoch [6/10]: 0it [00:00, ?it/s]
# Epoch: [6/10], Loss: 0.1124
# epoch [7/10]: 0it [00:00, ?it/s]
# Epoch: [7/10], Loss: 0.1086
# epoch [8/10]: 0it [00:00, ?it/s]
# Epoch: [8/10], Loss: 0.1050
# epoch [9/10]: 0it [00:00, ?it/s]
# Epoch: [9/10], Loss: 0.1015
# epoch [10/10]: 0it [00:00, ?it/s]
# Epoch: [10/10], Loss: 0.0981

# %%
linear_probe.evaluate_probe(probe_selected, X_selected, y, idx_to_class=idx2label)
# Out:
# Evaluating: 0it [00:00, ?it/s]
# Score (accuracy) of the probe: 0.49
# {'__OVERALL__': 0.49295774647887325,
#  'VBZ': 0.8,
#  'NNP': 0.0,
#  'VBN': 0.0,
#  'CC': 0.0,
#  'NNS': 0.3333333333333333,
#  'PRP': 0.0,
#  'RB': 0.0,
#  'VBP': 0.5,
#  'JJ': 0.0,
#  'MD': 0.0,
#  'EX': 0.0,
#  'VB': 0.0,
#  'CD': 0.0,
#  'VBG': 0.0,
#  'IN': 0.4,
#  '.': 0.9,
#  'DT': 0.8461538461538461,
#  'NN': 0.5384615384615384,
#  'JJR': 0.0}

# %% [markdown]
# # Further analysis

# %%
top_neurons, top_neurons_per_class = linear_probe.get_top_neurons(probe, 0.01, label2idx)
print(top_neurons)
# Out:
# [  10 8205 6159 8208 8213   21 8219 6184 6186 8237 4149 6201 4163 6212
#  4167 4174 6225 4177 4179 2136 2139 4187 8284 8286 6238 6241 2147 4195
#  8295 4204 6252  115 4212 8308 4223 6273 8336 8346 8347 6302 4257  168
#  8360 6317 2228 2230 8377 6331  189  191 2247  203 8400 6372 8427 2285
#  4339 8450 4362 6412 6415 6418 2324 8468 4388 6437  308 4407 6458 8508
#  6471 2378  330 6482 8538  355 4456 6508 4464 2421 2423  376  379  382
#  6530 2444 6548 8596 6555 4519 6574 4528 6578 6584 4557 2510 8659 8669
#  4575 6624 4576  484 6642 2555 6679 8730  541  548 4649  554 6701 2611
#  8756 8757 8762 6715 8767 8769 2631 6731  594  599  622 6774 4727 4731
#  6786  644 6800 6801 6802  661 2717 8862 2719 2721  678 6823 4777 4781
#  2736 2738 4787 6836 8882  694 6838 4791 8891 4798 2751 2768  721 8927
#  2785 8931 2791 6887 2793 2794  748  770 4870  775  778 4881 4887  793
#  4899 4901 8997  809 2861 4910 4917 4925 4931  849 2897  853 4950  862
#  7007  868 2919  873 4972 4973 7021 2929 9073 4978  885 2934 7041 2950
#   902 9098 2964 2968 7064 2986 2991 2992 2997 3005 5054  957 5057 5059
#   968 7117  974 5070  978 5078 5080 3033 5084 9182 5095 9202 3059 3060
#  5111 5112 1017 1018 3068 3081 1037 9231 3092 3101 1063 3112 3122 1076
#  1081 3130 5179 3143 7241 1102 3155 1107 3161 1117 3171 3175 7271 7276
#  5230 3183 1136 5233 7286 1148 9341 7302 3207 5258 7307 1168 7314 3229
#  7328 7329 5287 3247 1204 9402 5310 7365 9413 3273 5329 5333 3293 7405
#  9467 7434 5391 1299 5395 1301 7447 3366 3368 5416 1321 1326 3380 7483
#  5436 9535 9538 5448 9545 5463 5466 7520 5478 5483 3445 3447 5498 1404
#  3456 3459 1415 9610 9613 1424 1430 1449 1463 5561 1473 1475 3529 1484
#  3537 7645 7648 3564 1517 1524 3576 3579 5649 1554 1553 1558 5661 5662
#  3614 5669 1573 1574 7720 3634 3639 7737 3644 3658 3677 5726 7777 1636
#  3689 1651 3705 3708 3713 3715 9863 5768 7824 1688 7836 7838 3742 7840
#  5793 7843 3752 3754 5803 1709 7853 3762 3765 1719 1723 1726 7880 5836
#  3794 5863 7922 1779 7931 5886 5889 3842 5898 1804 1807 3867 1820 7965
#  3875 1829 7974 5931 3887 1843 5943 8007 3911 1868 1872 1877 8026 1882
#  5980 3940 3943 8045 6001 3960 6011 1915 1918 1919 6027 8078 6037 6038
#  8089 8094 8110 6069 1981 1982 8133 1991 1995 4052 6111 6115 2022 6119
#  2025 2026 2029 8187 6140 2045]

# %%
X_zeroed = ablation.zero_out_activations_keep_neurons(X, top_neurons)
linear_probe.evaluate_probe(probe, X_zeroed, y, idx_to_class=idx2label)
# Out:
# Evaluating: 0it [00:00, ?it/s]
# Score (accuracy) of the probe: 0.96
# {'__OVERALL__': 0.9577464788732394,
#  'VBZ': 1.0,
#  'NNP': 1.0,
#  'VBN': 0.0,
#  'CC': 1.0,
#  'NNS': 1.0,
#  'PRP': 1.0,
#  'RB': 1.0,
#  'VBP': 1.0,
#  'JJ': 1.0,
#  'MD': 1.0,
#  'EX': 1.0,
#  'VB': 1.0,
#  'CD': 1.0,
#  'VBG': 1.0,
#  'IN': 1.0,
#  '.': 1.0,
#  'DT': 1.0,
#  'NN': 1.0,
#  'JJR': 0.0}

# %%
import neurox.analysis.visualization as visualization

# Visualize a single sentence
visualization.visualize_activations(
    tokens["source"][9],
    activations[9][:, 2]
)

# %%
# Visualize entire dataset using transformer model
from IPython.display import display
from neurox.analysis.visualization import TransformersVisualizer

viz = TransformersVisualizer('bert-base-uncased')
for s_idx in range(len(tokens["source"])):
    display(viz(tokens["source"][s_idx], 0, 5))
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
## Filtered visualization
for s_idx in range(len(tokens["source"])):
    display(viz(tokens["source"][s_idx], 0, 5, filter_fn="top_tokens"))

# %% [markdown]
# ### Top words per neuron

# %%
from neurox.analysis.corpus import get_top_words

# %%
print(get_top_words(tokens, activations, 0))
# Out:
# [('can', 1.0), ('<<UNKNOWN>>', 0.8374996042373963), ('this', 0.7417334743790905), ('There', 0.6959218411824226), ('sentence', 0.6481815429944557), ('red', 0.6246387699270328), ('!', 0.6154971458274725), ('than', 0.6124322592376957), ('more', 0.5898240359082019), ('word', 0.5344059976535159), ('insightful', 0.528528552864625), ('be', 0.5191353847779002), ('test', 0.5111003941732798), ('This', 0.47618579649353443), ('toolkit', 0.4664674003831317), ('question', 0.465488154669146), ('you', 0.46063812941643245), ('quickly', 0.45942280447544265), ('is', 0.4592116301522393), ('10000', 0.45776577348935954), ('the', 0.4574250986964273), ('car', 0.42620446047912103), ('?', 0.3775879389218368), ('Hope', 0.3771822296748212), ('a', 0.3493998052587224), ('neuron', 0.3336644772676553), ('The', 0.3088258036671118), ('It', 0.2977828964753988), ('NeuroX', 0.2847366657793814), ('zoomed', 0.28037167742755276), ('beautiful', 0.26925516302234914), ('analysis', 0.2679976932899512), ('used', 0.26194879375805263), ('enjoying', 0.2614234297778666), ('contains', 0.2405393665864081), ('an', 0.23575143655598124), ('by', 0.2224696489998406), ('day', 0.22223262953470813), ('Is', 0.19324402927662523), ('some', 0.1880681922046105), ('.', 0.179653691730277), ('another', 0.1742539770305787), ('in', 0.17173028263454265), ('tutorial', 0.14930923780307273), ('Individual', 0.1489316101716127)]
